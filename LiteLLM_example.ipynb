# %% [markdown]
# <a href="https://colab.research.google.com/github/hbanerjee74/litellm-playground/blob/main/LiteLLM_example.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # LiteLLM Testing

# %%
# !pip install litellm
# Out:
# Collecting litellm
#   Downloading litellm-1.87.0-py3-none-any.whl.metadata (33 kB)
# Collecting fastuuid<1.0,>=0.14.0 (from litellm)
#   Downloading fastuuid-0.14.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.1 kB)
# Requirement already satisfied: httpx<1.0,>=0.28.0 in /usr/local/lib/python3.12/dist-packages (from litellm) (0.28.1)
# Requirement already satisfied: openai<3.0.0,>=2.20.0 in /usr/local/lib/python3.12/dist-packages (from litellm) (2.37.0)
# Requirement already satisfied: python-dotenv<2.0,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from litellm) (1.2.2)
# Requirement already satisfied: tiktoken<1.0,>=0.8.0 in /usr/local/lib/python3.12/dist-packages (from litellm) (0.13.0)
# Requirement already satisfied: importlib-metadata<9.0,>=8.0.0 in /usr/local/lib/python3.12/dist-packages (from litellm) (8.7.1)
# Requirement already satisfied: tokenizers<1.0,>=0.21.0 in /usr/local/lib/python3.12/dist-packages (from litellm) (0.22.2)
# Requirement already satisfied: click<9.0,>=8.0.0 in /usr/local/lib/python3.12/dist-packages (from litellm) (8.4.0)
# Requirement already satisfied: jinja2<4.0,>=3.1.6 in /usr/local/lib/python3.12/dist-packages (from litellm) (3.1.6)
# Requirement already satisfied: aiohttp<4.0,>=3.10 in /usr/local/lib/python3.12/dist-packages (from litellm) (3.13.5)
# Requirement already satisfied: pydantic<3.0.0,>=2.10.0 in /usr/local/lib/python3.12/dist-packages (from litellm) (2.12.3)
# Requirement already satisfied: jsonschema<5.0,>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from litellm) (4.26.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0,>=3.10->litellm) (2.6.2)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0,>=3.10->litellm) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0,>=3.10->litellm) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0,>=3.10->litellm) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0,>=3.10->litellm) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0,>=3.10->litellm) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0,>=3.10->litellm) (1.24.2)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1.0,>=0.28.0->litellm) (4.13.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1.0,>=0.28.0->litellm) (2026.5.20)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1.0,>=0.28.0->litellm) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx<1.0,>=0.28.0->litellm) (3.15)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1.0,>=0.28.0->litellm) (0.16.0)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.12/dist-packages (from importlib-metadata<9.0,>=8.0.0->litellm) (4.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2<4.0,>=3.1.6->litellm) (3.0.3)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema<5.0,>=4.0.0->litellm) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema<5.0,>=4.0.0->litellm) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema<5.0,>=4.0.0->litellm) (0.30.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from openai<3.0.0,>=2.20.0->litellm) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in /usr/local/lib/python3.12/dist-packages (from openai<3.0.0,>=2.20.0->litellm) (0.15.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from openai<3.0.0,>=2.20.0->litellm) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.12/dist-packages (from openai<3.0.0,>=2.20.0->litellm) (4.67.3)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /usr/local/lib/python3.12/dist-packages (from openai<3.0.0,>=2.20.0->litellm) (4.15.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.10.0->litellm) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.10.0->litellm) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.10.0->litellm) (0.4.2)
# Requirement already satisfied: regex in /usr/local/lib/python3.12/dist-packages (from tiktoken<1.0,>=0.8.0->litellm) (2025.11.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from tiktoken<1.0,>=0.8.0->litellm) (2.32.4)
# Requirement already satisfied: huggingface-hub<2.0,>=0.16.4 in /usr/local/lib/python3.12/dist-packages (from tokenizers<1.0,>=0.21.0->litellm) (1.16.1)
# Requirement already satisfied: filelock>=3.10.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers<1.0,>=0.21.0->litellm) (3.29.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers<1.0,>=0.21.0->litellm) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers<1.0,>=0.21.0->litellm) (1.5.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers<1.0,>=0.21.0->litellm) (26.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers<1.0,>=0.21.0->litellm) (6.0.3)
# Requirement already satisfied: typer>=0.20.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers<1.0,>=0.21.0->litellm) (0.25.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->tiktoken<1.0,>=0.8.0->litellm) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->tiktoken<1.0,>=0.8.0->litellm) (2.5.0)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer>=0.20.0->huggingface-hub<2.0,>=0.16.4->tokenizers<1.0,>=0.21.0->litellm) (1.5.4)
# Requirement already satisfied: rich>=13.8.0 in /usr/local/lib/python3.12/dist-packages (from typer>=0.20.0->huggingface-hub<2.0,>=0.16.4->tokenizers<1.0,>=0.21.0->litellm) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer>=0.20.0->huggingface-hub<2.0,>=0.16.4->tokenizers<1.0,>=0.21.0->litellm) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.8.0->typer>=0.20.0->huggingface-hub<2.0,>=0.16.4->tokenizers<1.0,>=0.21.0->litellm) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.8.0->typer>=0.20.0->huggingface-hub<2.0,>=0.16.4->tokenizers<1.0,>=0.21.0->litellm) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer>=0.20.0->huggingface-hub<2.0,>=0.16.4->tokenizers<1.0,>=0.21.0->litellm) (0.1.2)
# Downloading litellm-1.87.0-py3-none-any.whl (17.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.1/17.1 MB 51.0 MB/s eta 0:00:00
# Downloading fastuuid-0.14.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (278 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.1/278.1 kB 15.6 MB/s eta 0:00:00
# Installing collected packages: fastuuid, litellm
# Successfully installed fastuuid-0.14.0 litellm-1.87.0

# %% [markdown]
# ### OpenAI

# %%
from litellm import completion
from google.colab import userdata

response = completion(
    api_base = "https://api.openai.com/v1",
    api_key = userdata.get('OPENAI_API_KEY'),
    model = "gpt-4o",
    messages=[{ "content": "Hello, how are you?","role": "user"}]
)

print("OpenAI Response\n")
print(response)
# Out:
# 15:45:34 - LiteLLM:DEBUG: utils.py:485 -
#
# DEBUG:LiteLLM:
#
# 15:45:34 - LiteLLM:DEBUG: utils.py:485 - Request to litellm:
# DEBUG:LiteLLM:Request to litellm:
# 15:45:34 - LiteLLM:DEBUG: utils.py:485 - litellm.completion(api_base='https://api.openai.com/v1', REDACTED', model='gpt-4o', messages=[{'content': 'Hello, how are you?', 'role': 'user'}])
# DEBUG:LiteLLM:litellm.completion(api_base='https://api.openai.com/v1', REDACTED', model='gpt-4o', messages=[{'content': 'Hello, how are you?', 'role': 'user'}])
# 15:45:34 - LiteLLM:DEBUG: utils.py:485 -
#
# DEBUG:LiteLLM:
#
# 15:45:34 - LiteLLM:DEBUG: utils.py:1011 - Removing thought signatures from tool call IDs for non-Gemini model
# DEBUG:LiteLLM:Removing thought signatures from tool call IDs for non-Gemini model
# 15:45:34 - LiteLLM:DEBUG: litellm_logging.py:563 - self.optional_params: {}
# DEBUG:LiteLLM:self.optional_params: {}
# 15:45:34 - LiteLLM:DEBUG: utils.py:485 - SYNC kwargs[caching]: False; litellm.cache: None; kwargs.get('cache')['no-cache']: False
# DEBUG:LiteLLM:SYNC kwargs[caching]: False; litellm.cache: None; kwargs.get('cache')['no-cache']: False
# 15:45:34 - LiteLLM:DEBUG: utils.py:5745 - checking potential_model_names in litellm.model_cost: {'split_model': 'gpt-4o', 'combined_model_name': 'openai/gpt-4o', 'stripped_model_name': 'gpt-4o', 'combined_stripped_model_name': 'openai/gpt-4o', 'custom_llm_provider': 'openai'}
# DEBUG:LiteLLM:checking potential_model_names in litellm.model_cost: {'split_model': 'gpt-4o', 'combined_model_name': 'openai/gpt-4o', 'stripped_model_name': 'gpt-4o', 'combined_stripped_model_name': 'openai/gpt-4o', 'custom_llm_provider': 'openai'}
# 15:45:34 - LiteLLM:INFO: utils.py:4083 -
# LiteLLM completion() model= gpt-4o; provider = openai
# INFO:LiteLLM:
# LiteLLM completion() model= gpt-4o; provider = openai
# 15:45:34 - LiteLLM:DEBUG: utils.py:4086 -
# LiteLLM: Params passed to completion() {'model': 'gpt-4o', 'functions': None, 'function_call': None, 'temperature': None, 'top_p': None, 'n': None, 'stream': None, 'stream_options': None, 'stop': None, 'max_tokens': None, 'max_completion_tokens': None, 'modalities': None, 'prediction': None, 'audio': None, 'presence_penalty': None, 'frequency_penalty': None, 'logit_bias': None, 'user': None, 'custom_llm_provider': 'openai', 'response_format': None, 'seed': None, 'tools': None, 'tool_choice': None, 'max_retries': None, 'logprobs': None, 'top_logprobs': None, 'extra_headers': None, 'api_version': None, 'parallel_tool_calls': None, 'drop_params': None, 'allowed_openai_params': None, 'reasoning_effort': None, 'verbosity': None, 'additional_drop_params': None, 'messages': [{'content': 'Hello, how are you?', 'role': 'user'}], 'thinking': None, 'web_search_options': None, 'safety_identifier': None, 'service_tier': None}
# DEBUG:LiteLLM:
# LiteLLM: Params passed to completion() {'model': 'gpt-4o', 'functions': None, 'function_call': None, 'temperature': None, 'top_p': None, 'n': None, 'stream': None, 'stream_options': None, 'stop': None, 'max_tokens': None, 'max_completion_tokens': None, 'modalities': None, 'prediction': None, 'audio': None, 'presence_penalty': None, 'frequency_penalty': None, 'logit_bias': None, 'user': None, 'custom_llm_provider': 'openai', 'response_format': None, 'seed': None, 'tools': None, 'tool_choice': None, 'max_retries': None, 'logprobs': None, 'top_logprobs': None, 'extra_headers': None, 'api_version': None, 'parallel_tool_calls': None, 'drop_params': None, 'allowed_openai_params': None, 'reasoning_effort': None, 'verbosity': None, 'additional_drop_params': None, 'messages': [{'content': 'Hello, how are you?', 'role': 'user'}], 'thinking': None, 'web_search_options': None, 'safety_identifier': None, 'service_tier': None}
# 15:45:34 - LiteLLM:DEBUG: utils.py:4089 -
# LiteLLM: Non-Default params passed to completion() {}
# DEBUG:LiteLLM:
# LiteLLM: Non-Default params passed to completion() {}
# 15:45:34 - LiteLLM:DEBUG: utils.py:485 - Final returned optional params: {'extra_body': {}}
# DEBUG:LiteLLM:Final returned optional params: {'extra_body': {}}
# 15:45:34 - LiteLLM:DEBUG: litellm_logging.py:563 - self.optional_params: {'extra_body': {}}
# DEBUG:LiteLLM:self.optional_params: {'extra_body': {}}
# 15:45:34 - LiteLLM:DEBUG: utils.py:5745 - checking potential_model_names in litellm.model_cost: {'split_model': 'gpt-4o', 'combined_model_name': 'openai/gpt-4o', 'stripped_model_name': 'gpt-4o', 'combined_stripped_model_name': 'openai/gpt-4o', 'custom_llm_provider': 'openai'}
# DEBUG:LiteLLM:checking potential_model_names in litellm.model_cost: {'split_model': 'gpt-4o', 'combined_model_name': 'openai/gpt-4o', 'stripped_model_name': 'gpt-4o', 'combined_stripped_model_name': 'openai/gpt-4o', 'custom_llm_provider': 'openai'}
# 15:45:34 - LiteLLM:DEBUG: litellm_logging.py:1170 -
#
# POST Request Sent from LiteLLM:
# curl -X POST \
# https://api.openai.com/v1/ \
# -d '{'model': 'gpt-4o', 'messages': [{'content': 'Hello, how are you?', 'role': 'user'}], 'extra_body': {}}'
#
#
# DEBUG:LiteLLM:
#
# POST Request Sent from LiteLLM:
# curl -X POST \
# https://api.openai.com/v1/ \
# -d '{'model': 'gpt-4o', 'messages': [{'content': 'Hello, how are you?', 'role': 'user'}], 'extra_body': {}}'
#
#
# 15:45:35 - LiteLLM:DEBUG: litellm_logging.py:1243 - RAW RESPONSE:
# {"id": "chatcmpl-DmLb4xRugQhJTODp4DE5rG4uylrKq", "choices": [{"finish_reason": "stop", "index": 0, "logprobs": null, "message": {"content": "Hello! I'm just a computer program, so I don't have feelings, but I'm here and ready to help you. How can I assist you today?", "refusal": null, "role": "assistant", "annotations": [], "audio": null, "function_call": null, "tool_calls": null}}], "created": 1780415134, "model": "gpt-4o-2024-08-06", "object": "chat.completion", "service_tier": "default", "system_fingerprint": "fp_c109d8e454", "usage": {"completion_tokens": 30, "prompt_tokens": 13, "total_tokens": 43, "completion_tokens_details": {"accepted_prediction_tokens": 0, "audio_tokens": 0, "reasoning_tokens": 0, "rejected_prediction_tokens": 0}, "prompt_tokens_details": {"audio_tokens": 0, "cached_tokens": 0}}}
#
#
# DEBUG:LiteLLM:RAW RESPONSE:
# {"id": "chatcmpl-DmLb4xRugQhJTODp4DE5rG4uylrKq", "choices": [{"finish_reason": "stop", "index": 0, "logprobs": null, "message": {"content": "Hello! I'm just a computer program, so I don't have feelings, but I'm here and ready to help you. How can I assist you today?", "refusal": null, "role": "assistant", "annotations": [], "audio": null, "function_call": null, "tool_calls": null}}], "created": 1780415134, "model": "gpt-4o-2024-08-06", "object": "chat.completion", "service_tier": "default", "system_fingerprint": "fp_c109d8e454", "usage": {"completion_tokens": 30, "prompt_tokens": 13, "total_tokens": 43, "completion_tokens_details": {"accepted_prediction_tokens": 0, "audio_tokens": 0, "reasoning_tokens": 0, "rejected_prediction_tokens": 0}, "prompt_tokens_details": {"audio_tokens": 0, "cached_tokens": 0}}}
#
#
# 15:45:35 - LiteLLM:INFO: utils.py:1656 - Wrapper: Completed Call, calling success_handler
# INFO:LiteLLM:Wrapper: Completed Call, calling success_handler
# 15:45:35 - LiteLLM:DEBUG: cost_calculator.py:1212 - selected model name for cost calculation: openai/gpt-4o-2024-08-06
# DEBUG:LiteLLM:selected model name for cost calculation: openai/gpt-4o-2024-08-06
# 15:45:35 - LiteLLM:DEBUG: litellm_logging.py:2017 - Logging Details LiteLLM-Success Call: Cache_hit=None
# DEBUG:LiteLLM:Logging Details LiteLLM-Success Call: Cache_hit=None
# 15:45:35 - LiteLLM:DEBUG: litellm_logging.py:1568 - response_cost: 0.0003325
# DEBUG:LiteLLM:response_cost: 0.0003325
# 15:45:35 - LiteLLM:DEBUG: cost_calculator.py:1212 - selected model name for cost calculation: openai/gpt-4o-2024-08-06
# OpenAI Response
#
# ModelResponse(id='chatcmpl-DmLb4xRugQhJTODp4DE5rG4uylrKq', created=1780415134, model='gpt-4o-2024-08-06', object='chat.completion', system_fingerprint='fp_c109d8e454', choices=[Choices(finish_reason='stop', index=0, message=Message(content="Hello! I'm just a computer program, so I don't have feelings, but I'm here and ready to help you. How can I assist you today?", role='assistant', tool_calls=None, function_call=None, provider_specific_fields={'refusal': None}, annotations=[]), provider_specific_fields={})], usage=Usage(completion_tokens=30, prompt_tokens=13, total_tokens=43, completion_tokens_details=CompletionTokensDetailsWrapper(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0, text_tokens=None, image_tokens=None, video_tokens=None), prompt_tokens_details=PromptTokensDetailsWrapper(audio_tokens=0, cached_tokens=0, text_tokens=None, image_tokens=None, video_tokens=None)), service_tier='default')
# DEBUG:LiteLLM:selected model name for cost calculation: openai/gpt-4o-2024-08-06
# 15:45:35 - LiteLLM:DEBUG: litellm_logging.py:1568 - response_cost: 0.0003325
# DEBUG:LiteLLM:response_cost: 0.0003325

# %% [markdown]
# ### *Foundry Kimi*

# %%
from litellm import completion
from google.colab import userdata

response = completion(
    api_base = "https://openhands-test.services.ai.azure.com/",
    api_key=userdata.get('AZURE_API_KEY'),
    model = "azure/My-Special-Kimi",
    messages = [{ "content": "Hello, how are you?","role": "user"}]
)
print("Azure Response\n")
print(response)
# Out:
# 15:45:55 - LiteLLM:DEBUG: utils.py:485 -
#
# DEBUG:LiteLLM:
#
# 15:45:55 - LiteLLM:DEBUG: utils.py:485 - Request to litellm:
# DEBUG:LiteLLM:Request to litellm:
# 15:45:55 - LiteLLM:DEBUG: utils.py:485 - litellm.completion(api_base='https://openhands-test.services.ai.azure.com/', REDACTED', model='azure/My-Special-Kimi', messages=[{'content': 'Hello, how are you?', 'role': 'user'}])
# DEBUG:LiteLLM:litellm.completion(api_base='https://openhands-test.services.ai.azure.com/', REDACTED', model='azure/My-Special-Kimi', messages=[{'content': 'Hello, how are you?', 'role': 'user'}])
# 15:45:55 - LiteLLM:DEBUG: utils.py:485 -
#
# DEBUG:LiteLLM:
#
# 15:45:55 - LiteLLM:DEBUG: utils.py:1011 - Removing thought signatures from tool call IDs for non-Gemini model
# DEBUG:LiteLLM:Removing thought signatures from tool call IDs for non-Gemini model
# 15:45:55 - LiteLLM:DEBUG: litellm_logging.py:563 - self.optional_params: {}
# DEBUG:LiteLLM:self.optional_params: {}
# 15:45:55 - LiteLLM:DEBUG: utils.py:485 - SYNC kwargs[caching]: False; litellm.cache: None; kwargs.get('cache')['no-cache']: False
# DEBUG:LiteLLM:SYNC kwargs[caching]: False; litellm.cache: None; kwargs.get('cache')['no-cache']: False
# 15:45:55 - LiteLLM:DEBUG: utils.py:5745 - checking potential_model_names in litellm.model_cost: {'split_model': 'My-Special-Kimi', 'combined_model_name': 'azure/My-Special-Kimi', 'stripped_model_name': 'My-Special-Kimi', 'combined_stripped_model_name': 'azure/My-Special-Kimi', 'custom_llm_provider': 'azure'}
# DEBUG:LiteLLM:checking potential_model_names in litellm.model_cost: {'split_model': 'My-Special-Kimi', 'combined_model_name': 'azure/My-Special-Kimi', 'stripped_model_name': 'My-Special-Kimi', 'combined_stripped_model_name': 'azure/My-Special-Kimi', 'custom_llm_provider': 'azure'}
# 15:45:55 - LiteLLM:DEBUG: utils.py:6050 - Error getting model info: This model isn't mapped yet. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json
# DEBUG:LiteLLM:Error getting model info: This model isn't mapped yet. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json
# 15:45:55 - LiteLLM:DEBUG: main.py:985 - Error getting model info: This model isn't mapped yet. model=My-Special-Kimi, custom_llm_provider=azure. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json.
# DEBUG:LiteLLM:Error getting model info: This model isn't mapped yet. model=My-Special-Kimi, custom_llm_provider=azure. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json.
# 15:45:55 - LiteLLM:INFO: utils.py:4083 -
# LiteLLM completion() model= My-Special-Kimi; provider = azure
# INFO:LiteLLM:
# LiteLLM completion() model= My-Special-Kimi; provider = azure
# 15:45:55 - LiteLLM:DEBUG: utils.py:4086 -
# LiteLLM: Params passed to completion() {'model': 'My-Special-Kimi', 'functions': None, 'function_call': None, 'temperature': None, 'top_p': None, 'n': None, 'stream': None, 'stream_options': None, 'stop': None, 'max_tokens': None, 'max_completion_tokens': None, 'modalities': None, 'prediction': None, 'audio': None, 'presence_penalty': None, 'frequency_penalty': None, 'logit_bias': None, 'user': None, 'custom_llm_provider': 'azure', 'response_format': None, 'seed': None, 'tools': None, 'tool_choice': None, 'max_retries': None, 'logprobs': None, 'top_logprobs': None, 'extra_headers': None, 'api_version': None, 'parallel_tool_calls': None, 'drop_params': None, 'allowed_openai_params': None, 'reasoning_effort': None, 'verbosity': None, 'additional_drop_params': None, 'messages': [{'content': 'Hello, how are you?', 'role': 'user'}], 'thinking': None, 'web_search_options': None, 'safety_identifier': None, 'service_tier': None}
# DEBUG:LiteLLM:
# LiteLLM: Params passed to completion() {'model': 'My-Special-Kimi', 'functions': None, 'function_call': None, 'temperature': None, 'top_p': None, 'n': None, 'stream': None, 'stream_options': None, 'stop': None, 'max_tokens': None, 'max_completion_tokens': None, 'modalities': None, 'prediction': None, 'audio': None, 'presence_penalty': None, 'frequency_penalty': None, 'logit_bias': None, 'user': None, 'custom_llm_provider': 'azure', 'response_format': None, 'seed': None, 'tools': None, 'tool_choice': None, 'max_retries': None, 'logprobs': None, 'top_logprobs': None, 'extra_headers': None, 'api_version': None, 'parallel_tool_calls': None, 'drop_params': None, 'allowed_openai_params': None, 'reasoning_effort': None, 'verbosity': None, 'additional_drop_params': None, 'messages': [{'content': 'Hello, how are you?', 'role': 'user'}], 'thinking': None, 'web_search_options': None, 'safety_identifier': None, 'service_tier': None}
# 15:45:55 - LiteLLM:DEBUG: utils.py:4089 -
# LiteLLM: Non-Default params passed to completion() {}
# DEBUG:LiteLLM:
# LiteLLM: Non-Default params passed to completion() {}
# 15:45:55 - LiteLLM:DEBUG: utils.py:4762 - Azure optional params - api_version: api_version=None, litellm.api_version=None, os.environ['AZURE_API_VERSION']=2023-05-15
# DEBUG:LiteLLM:Azure optional params - api_version: api_version=None, litellm.api_version=None, os.environ['AZURE_API_VERSION']=2023-05-15
# 15:45:55 - LiteLLM:DEBUG: utils.py:485 - Final returned optional params: {'extra_body': {}}
# DEBUG:LiteLLM:Final returned optional params: {'extra_body': {}}
# 15:45:55 - LiteLLM:DEBUG: litellm_logging.py:563 - self.optional_params: {'extra_body': {}}
# DEBUG:LiteLLM:self.optional_params: {'extra_body': {}}
# 15:45:55 - LiteLLM:DEBUG: utils.py:5745 - checking potential_model_names in litellm.model_cost: {'split_model': 'My-Special-Kimi', 'combined_model_name': 'azure/My-Special-Kimi', 'stripped_model_name': 'My-Special-Kimi', 'combined_stripped_model_name': 'azure/My-Special-Kimi', 'custom_llm_provider': 'azure'}
# DEBUG:LiteLLM:checking potential_model_names in litellm.model_cost: {'split_model': 'My-Special-Kimi', 'combined_model_name': 'azure/My-Special-Kimi', 'stripped_model_name': 'My-Special-Kimi', 'combined_stripped_model_name': 'azure/My-Special-Kimi', 'custom_llm_provider': 'azure'}
# 15:45:55 - LiteLLM:DEBUG: utils.py:6050 - Error getting model info: This model isn't mapped yet. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json
# DEBUG:LiteLLM:Error getting model info: This model isn't mapped yet. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json
# 15:45:55 - LiteLLM:DEBUG: main.py:985 - Error getting model info: This model isn't mapped yet. model=My-Special-Kimi, custom_llm_provider=azure. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json.
# DEBUG:LiteLLM:Error getting model info: This model isn't mapped yet. model=My-Special-Kimi, custom_llm_provider=azure. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json.
# 15:45:55 - LiteLLM:DEBUG: litellm_logging.py:1170 -
#
# POST Request Sent from LiteLLM:
# curl -X POST \
# https://openhands-test.services.ai.azure.com/ \
# -H 'REDACTED' -H 'azure_ad_token: None' \
# -d '{'model': 'My-Special-Kimi', 'messages': [{'content': 'Hello, how are you?', 'role': 'user'}], 'extra_body': {}}'
#
#
# DEBUG:LiteLLM:
#
# POST Request Sent from LiteLLM:
# curl -X POST \
# https://openhands-test.services.ai.azure.com/ \
# -H 'REDACTED' -H 'azure_ad_token: None' \
# -d '{'model': 'My-Special-Kimi', 'messages': [{'content': 'Hello, how are you?', 'role': 'user'}], 'extra_body': {}}'
#
#
# 15:45:55 - LiteLLM:DEBUG: common_utils.py:617 - Initializing Azure OpenAI Client for My-Special-Kimi, Api Base: https://openhands-test.services.ai.azure.com/, Api Key:F4f9Nuj5***************
# DEBUG:LiteLLM:Initializing Azure OpenAI Client for My-Special-Kimi, Api Base: https://openhands-test.services.ai.azure.com/, Api Key:F4f9Nuj5***************
# 15:45:56 - LiteLLM:DEBUG: litellm_logging.py:1243 - RAW RESPONSE:
# {"id": "62abdcdef7e24fc686db819afda02e83", "choices": [{"finish_reason": "stop", "index": 0, "logprobs": null, "message": {"content": "Hello! I'm doing well, thank you. As an AI, I don't have feelings, but I'm fully operational and ready to help. How can I assist you today?", "refusal": null, "role": "assistant", "annotations": null, "audio": null, "function_call": null, "tool_calls": null, "reasoning_content": "The user greeted me and asked \"how are you?\" This is a standard conversational opening. I should respond politely, briefly mention that I'm an AI without personal feelings (to be accurate), and ask how I can help them today. Keep it friendly and open-ended to invite them to ask whatever they need.\n\nPlan:\n1. Return greeting\n2. State I'm doing well/functioning well (as an AI)\n3. Ask how I can assist them\n4. Keep tone warm and helpful\n\nNo safety concerns here."}, "content_filter_results": {}}], "created": 1780415155, "model": "Kimi-K2.6", "object": "chat.completion", "service_tier": null, "system_fingerprint": null, "usage": {"completion_tokens": 140, "prompt_tokens": 14, "total_tokens": 154, "completion_tokens_details": null, "prompt_tokens_details": {"audio_tokens": null, "cached_tokens": 2}, "audio_prompt_tokens": 0}, "prompt_filter_results": null}
#
#
# DEBUG:LiteLLM:RAW RESPONSE:
# {"id": "62abdcdef7e24fc686db819afda02e83", "choices": [{"finish_reason": "stop", "index": 0, "logprobs": null, "message": {"content": "Hello! I'm doing well, thank you. As an AI, I don't have feelings, but I'm fully operational and ready to help. How can I assist you today?", "refusal": null, "role": "assistant", "annotations": null, "audio": null, "function_call": null, "tool_calls": null, "reasoning_content": "The user greeted me and asked \"how are you?\" This is a standard conversational opening. I should respond politely, briefly mention that I'm an AI without personal feelings (to be accurate), and ask how I can help them today. Keep it friendly and open-ended to invite them to ask whatever they need.\n\nPlan:\n1. Return greeting\n2. State I'm doing well/functioning well (as an AI)\n3. Ask how I can assist them\n4. Keep tone warm and helpful\n\nNo safety concerns here."}, "content_filter_results": {}}], "created": 1780415155, "model": "Kimi-K2.6", "object": "chat.completion", "service_tier": null, "system_fingerprint": null, "usage": {"completion_tokens": 140, "prompt_tokens": 14, "total_tokens": 154, "completion_tokens_details": null, "prompt_tokens_details": {"audio_tokens": null, "cached_tokens": 2}, "audio_prompt_tokens": 0}, "prompt_filter_results": null}
#
#
# 15:45:56 - LiteLLM:INFO: utils.py:1656 - Wrapper: Completed Call, calling success_handler
# INFO:LiteLLM:Wrapper: Completed Call, calling success_handler
# 15:45:56 - LiteLLM:DEBUG: cost_calculator.py:1212 - selected model name for cost calculation: azure/Kimi-K2.6
# DEBUG:LiteLLM:selected model name for cost calculation: azure/Kimi-K2.6
# 15:45:56 - LiteLLM:DEBUG: litellm_logging.py:2017 - Logging Details LiteLLM-Success Call: Cache_hit=None
# DEBUG:LiteLLM:Logging Details LiteLLM-Success Call: Cache_hit=None
# 15:45:56 - LiteLLM:DEBUG: cost_calculator.py:1212 - selected model name for cost calculation: azure/Kimi-K2.6
# DEBUG:LiteLLM:selected model name for cost calculation: azure/Kimi-K2.6
# 15:45:56 - LiteLLM:DEBUG: utils.py:5745 - checking potential_model_names in litellm.model_cost: {'split_model': 'Kimi-K2.6', 'combined_model_name': 'azure/Kimi-K2.6', 'stripped_model_name': 'Kimi-K2.6', 'combined_stripped_model_name': 'azure/Kimi-K2.6', 'custom_llm_provider': 'azure'}
# DEBUG:LiteLLM:checking potential_model_names in litellm.model_cost: {'split_model': 'Kimi-K2.6', 'combined_model_name': 'azure/Kimi-K2.6', 'stripped_model_name': 'Kimi-K2.6', 'combined_stripped_model_name': 'azure/Kimi-K2.6', 'custom_llm_provider': 'azure'}
# 15:45:56 - LiteLLM:DEBUG: utils.py:5745 - checking potential_model_names in litellm.model_cost: {'split_model': 'Kimi-K2.6', 'combined_model_name': 'azure/Kimi-K2.6', 'stripped_model_name': 'Kimi-K2.6', 'combined_stripped_model_name': 'azure/Kimi-K2.6', 'custom_llm_provider': 'azure'}
# DEBUG:LiteLLM:checking potential_model_names in litellm.model_cost: {'split_model': 'Kimi-K2.6', 'combined_model_name': 'azure/Kimi-K2.6', 'stripped_model_name': 'Kimi-K2.6', 'combined_stripped_model_name': 'azure/Kimi-K2.6', 'custom_llm_provider': 'azure'}
# 15:45:56 - LiteLLM:DEBUG: utils.py:6050 - Error getting model info: This model isn't mapped yet. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json
# 15:45:56 - LiteLLM:DEBUG: utils.py:6050 - Error getting model info: This model isn't mapped yet. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json
# DEBUG:LiteLLM:Error getting model info: This model isn't mapped yet. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json
# 15:45:56 - LiteLLM:DEBUG: cost_calculator.py:1730 - litellm.cost_calculator.py::completion_cost() - Error calculating cost for model=azure/Kimi-K2.6 - This model isn't mapped yet. model=azure/Kimi-K2.6, custom_llm_provider=azure. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json.
# DEBUG:LiteLLM:Error getting model info: This model isn't mapped yet. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json
# 15:45:56 - LiteLLM:DEBUG: cost_calculator.py:1730 - litellm.cost_calculator.py::completion_cost() - Error calculating cost for model=azure/Kimi-K2.6 - This model isn't mapped yet. model=azure/Kimi-K2.6, custom_llm_provider=azure. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json.
# DEBUG:LiteLLM:litellm.cost_calculator.py::completion_cost() - Error calculating cost for model=azure/Kimi-K2.6 - This model isn't mapped yet. model=azure/Kimi-K2.6, custom_llm_provider=azure. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json.
# DEBUG:LiteLLM:litellm.cost_calculator.py::completion_cost() - Error calculating cost for model=azure/Kimi-K2.6 - This model isn't mapped yet. model=azure/Kimi-K2.6, custom_llm_provider=azure. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json.
# 15:45:56 - LiteLLM:DEBUG: cost_calculator.py:1212 - selected model name for cost calculation: Kimi-K2.6
# DEBUG:LiteLLM:selected model name for cost calculation: Kimi-K2.6
# 15:45:56 - LiteLLM:DEBUG: cost_calculator.py:1212 - selected model name for cost calculation: Kimi-K2.6
# 15:45:56 - LiteLLM:DEBUG: utils.py:5745 - checking potential_model_names in litellm.model_cost: {'split_model': 'Kimi-K2.6', 'combined_model_name': 'azure/Kimi-K2.6', 'stripped_model_name': 'Kimi-K2.6', 'combined_stripped_model_name': 'azure/Kimi-K2.6', 'custom_llm_provider': 'azure'}
# DEBUG:LiteLLM:selected model name for cost calculation: Kimi-K2.6
# DEBUG:LiteLLM:checking potential_model_names in litellm.model_cost: {'split_model': 'Kimi-K2.6', 'combined_model_name': 'azure/Kimi-K2.6', 'stripped_model_name': 'Kimi-K2.6', 'combined_stripped_model_name': 'azure/Kimi-K2.6', 'custom_llm_provider': 'azure'}
# 15:45:56 - LiteLLM:DEBUG: utils.py:5745 - checking potential_model_names in litellm.model_cost: {'split_model': 'Kimi-K2.6', 'combined_model_name': 'azure/Kimi-K2.6', 'stripped_model_name': 'Kimi-K2.6', 'combined_stripped_model_name': 'azure/Kimi-K2.6', 'custom_llm_provider': 'azure'}
# 15:45:56 - LiteLLM:DEBUG: utils.py:6050 - Error getting model info: This model isn't mapped yet. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json
# DEBUG:LiteLLM:checking potential_model_names in litellm.model_cost: {'split_model': 'Kimi-K2.6', 'combined_model_name': 'azure/Kimi-K2.6', 'stripped_model_name': 'Kimi-K2.6', 'combined_stripped_model_name': 'azure/Kimi-K2.6', 'custom_llm_provider': 'azure'}
# 15:45:56 - LiteLLM:DEBUG: utils.py:6050 - Error getting model info: This model isn't mapped yet. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json
# DEBUG:LiteLLM:Error getting model info: This model isn't mapped yet. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json
# DEBUG:LiteLLM:Error getting model info: This model isn't mapped yet. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json
# 15:45:56 - LiteLLM:DEBUG: cost_calculator.py:1730 - litellm.cost_calculator.py::completion_cost() - Error calculating cost for model=Kimi-K2.6 - This model isn't mapped yet. model=Kimi-K2.6, custom_llm_provider=azure. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json.
# DEBUG:LiteLLM:litellm.cost_calculator.py::completion_cost() - Error calculating cost for model=Kimi-K2.6 - This model isn't mapped yet. model=Kimi-K2.6, custom_llm_provider=azure. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json.
# 15:45:56 - LiteLLM:DEBUG: cost_calculator.py:1730 - litellm.cost_calculator.py::completion_cost() - Error calculating cost for model=Kimi-K2.6 - This model isn't mapped yet. model=Kimi-K2.6, custom_llm_provider=azure. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json.
# DEBUG:LiteLLM:litellm.cost_calculator.py::completion_cost() - Error calculating cost for model=Kimi-K2.6 - This model isn't mapped yet. model=Kimi-K2.6, custom_llm_provider=azure. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json.
# 15:45:56 - LiteLLM:DEBUG: cost_calculator.py:1212 - selected model name for cost calculation: azure/My-Special-Kimi
# DEBUG:LiteLLM:selected model name for cost calculation: azure/My-Special-Kimi
# 15:45:56 - LiteLLM:DEBUG: cost_calculator.py:1212 - selected model name for cost calculation: My-Special-Kimi
# DEBUG:LiteLLM:selected model name for cost calculation: My-Special-Kimi
# 15:45:56 - LiteLLM:DEBUG: utils.py:5745 - checking potential_model_names in litellm.model_cost: {'split_model': 'My-Special-Kimi', 'combined_model_name': 'azure/My-Special-Kimi', 'stripped_model_name': 'My-Special-Kimi', 'combined_stripped_model_name': 'azure/My-Special-Kimi', 'custom_llm_provider': 'azure'}
# DEBUG:LiteLLM:checking potential_model_names in litellm.model_cost: {'split_model': 'My-Special-Kimi', 'combined_model_name': 'azure/My-Special-Kimi', 'stripped_model_name': 'My-Special-Kimi', 'combined_stripped_model_name': 'azure/My-Special-Kimi', 'custom_llm_provider': 'azure'}
# 15:45:56 - LiteLLM:DEBUG: utils.py:5745 - checking potential_model_names in litellm.model_cost: {'split_model': 'My-Special-Kimi', 'combined_model_name': 'azure/My-Special-Kimi', 'stripped_model_name': 'My-Special-Kimi', 'combined_stripped_model_name': 'azure/My-Special-Kimi', 'custom_llm_provider': 'azure'}
# DEBUG:LiteLLM:checking potential_model_names in litellm.model_cost: {'split_model': 'My-Special-Kimi', 'combined_model_name': 'azure/My-Special-Kimi', 'stripped_model_name': 'My-Special-Kimi', 'combined_stripped_model_name': 'azure/My-Special-Kimi', 'custom_llm_provider': 'azure'}
# 15:45:56 - LiteLLM:DEBUG: utils.py:6050 - Error getting model info: This model isn't mapped yet. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json
# DEBUG:LiteLLM:Error getting model info: This model isn't mapped yet. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json
# 15:45:56 - LiteLLM:DEBUG: utils.py:6050 - Error getting model info: This model isn't mapped yet. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json
# DEBUG:LiteLLM:Error getting model info: This model isn't mapped yet. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json
# 15:45:56 - LiteLLM:DEBUG: cost_calculator.py:1730 - litellm.cost_calculator.py::completion_cost() - Error calculating cost for model=azure/My-Special-Kimi - This model isn't mapped yet. model=azure/My-Special-Kimi, custom_llm_provider=azure. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json.
# DEBUG:LiteLLM:litellm.cost_calculator.py::completion_cost() - Error calculating cost for model=azure/My-Special-Kimi - This model isn't mapped yet. model=azure/My-Special-Kimi, custom_llm_provider=azure. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json.
# 15:45:56 - LiteLLM:DEBUG: cost_calculator.py:1730 - litellm.cost_calculator.py::completion_cost() - Error calculating cost for model=My-Special-Kimi - This model isn't mapped yet. model=My-Special-Kimi, custom_llm_provider=azure. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json.
# DEBUG:LiteLLM:litellm.cost_calculator.py::completion_cost() - Error calculating cost for model=My-Special-Kimi - This model isn't mapped yet. model=My-Special-Kimi, custom_llm_provider=azure. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json.
# 15:45:56 - LiteLLM:DEBUG: litellm_logging.py:1583 - response_cost_failure_debug_information: {'error_str': "This model isn't mapped yet. model=azure/My-Special-Kimi, custom_llm_provider=azure. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json.", 'traceback_str': 'Traceback (most recent call last):\n  File "/usr/local/lib/python3.12/dist-packages/litellm/utils.py", line 5841, in _get_model_info_helper\n    raise ValueError(\nValueError: This model isn\'t mapped yet. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json\n\nDuring handling of the above exception, another exception occurred:\n\nTraceback (most recent call last):\n  File "/usr/local/lib/python3.12/dist-packages/litellm/litellm_core_utils/litellm_logging.py", line 1564, in _response_cost_calculator\n    response_cost = litellm.response_cost_calculator(\n                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "/usr/local/lib/python3.12/dist-packages/litellm/cost_calculator.py", line 1850, in response_cost_calculator\n    raise e\n  File "/usr/local/lib/python3.12/dist-packages/litellm/cost_calculator.py", line 1833, in response_cost_calculator\n    response_cost = completion_cost(\n                    ^^^^^^^^^^^^^^^^\n  File "/usr/local/lib/python3.12/dist-packages/litellm/cost_calculator.py", line 1743, in completion_cost\n    raise e\n  File "/usr/local/lib/python3.12/dist-packages/litellm/cost_calculator.py", line 1736, in completion_cost\n    raise e\n  File "/usr/local/lib/python3.12/dist-packages/litellm/cost_calculator.py", line 1585, in completion_cost\n    ) = cost_per_token(\n        ^^^^^^^^^^^^^^^\n  File "/usr/local/lib/python3.12/dist-packages/litellm/cost_calculator.py", line 589, in cost_per_token\n    return azure_openai_cost_per_token(\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "/usr/local/lib/python3.12/dist-packages/litellm/llms/azure/cost_calculation.py", line 31, in cost_per_token\n    model_info = get_model_info(model=model, custom_llm_provider="azure")\n                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "/usr/local/lib/python3.12/dist-packages/litellm/utils.py", line 6138, in get_model_info\n    _model_info = _get_model_info_helper(\n                  ^^^^^^^^^^^^^^^^^^^^^^^\n  File "/usr/local/lib/python3.12/dist-packages/litellm/utils.py", line 6051, in _get_model_info_helper\n    raise Exception(\nException: This model isn\'t mapped yet. model=azure/My-Special-Kimi, custom_llm_provider=azure. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json.\n', 'model': 'azure/My-Special-Kimi', 'cache_hit': False, 'custom_llm_provider': 'azure', 'base_model': None, 'call_type': 'completion', 'custom_pricing': False}
# DEBUG:LiteLLM:response_cost_failure_debug_information: {'error_str': "This model isn't mapped yet. model=azure/My-Special-Kimi, custom_llm_provider=azure. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json.", 'traceback_str': 'Traceback (most recent call last):\n  File "/usr/local/lib/python3.12/dist-packages/litellm/utils.py", line 5841, in _get_model_info_helper\n    raise ValueError(\nValueError: This model isn\'t mapped yet. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json\n\nDuring handling of the above exception, another exception occurred:\n\nTraceback (most recent call last):\n  File "/usr/local/lib/python3.12/dist-packages/litellm/litellm_core_utils/litellm_logging.py", line 1564, in _response_cost_calculator\n    response_cost = litellm.response_cost_calculator(\n                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "/usr/local/lib/python3.12/dist-packages/litellm/cost_calculator.py", line 1850, in response_cost_calculator\n    raise e\n  File "/usr/local/lib/python3.12/dist-packages/litellm/cost_calculator.py", line 1833, in response_cost_calculator\n    response_cost = completion_cost(\n                    ^^^^^^^^^^^^^^^^\n  File "/usr/local/lib/python3.12/dist-packages/litellm/cost_calculator.py", line 1743, in completion_cost\n    raise e\n  File "/usr/local/lib/python3.12/dist-packages/litellm/cost_calculator.py", line 1736, in completion_cost\n    raise e\n  File "/usr/local/lib/python3.12/dist-packages/litellm/cost_calculator.py", line 1585, in completion_cost\n    ) = cost_per_token(\n        ^^^^^^^^^^^^^^^\n  File "/usr/local/lib/python3.12/dist-packages/litellm/cost_calculator.py", line 589, in cost_per_token\n    return azure_openai_cost_per_token(\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "/usr/local/lib/python3.12/dist-packages/litellm/llms/azure/cost_calculation.py", line 31, in cost_per_token\n    model_info = get_model_info(model=model, custom_llm_provider="azure")\n                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "/usr/local/lib/python3.12/dist-packages/litellm/utils.py", line 6138, in get_model_info\n    _model_info = _get_model_info_helper(\n                  ^^^^^^^^^^^^^^^^^^^^^^^\n  File "/usr/local/lib/python3.12/dist-packages/litellm/utils.py", line 6051, in _get_model_info_helper\n    raise Exception(\nException: This model isn\'t mapped yet. model=azure/My-Special-Kimi, custom_llm_provider=azure. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json.\n', 'model': 'azure/My-Special-Kimi', 'cache_hit': False, 'custom_llm_provider': 'azure', 'base_model': None, 'call_type': 'completion', 'custom_pricing': False}
# 15:45:56 - LiteLLM:DEBUG: litellm_logging.py:1583 - response_cost_failure_debug_information: {'error_str': "This model isn't mapped yet. model=My-Special-Kimi, custom_llm_provider=azure. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json.", 'traceback_str': 'Traceback (most recent call last):\n  File "/usr/local/lib/python3.12/dist-packages/litellm/utils.py", line 5841, in _get_model_info_helper\n    raise ValueError(\nValueError: This model isn\'t mapped yet. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json\n\nDuring handling of the above exception, another exception occurred:\n\nTraceback (most recent call last):\n  File "/usr/local/lib/python3.12/dist-packages/litellm/litellm_core_utils/litellm_logging.py", line 1564, in _response_cost_calculator\n    response_cost = litellm.response_cost_calculator(\n                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "/usr/local/lib/python3.12/dist-packages/litellm/cost_calculator.py", line 1850, in response_cost_calculator\n    raise e\n  File "/usr/local/lib/python3.12/dist-packages/litellm/cost_calculator.py", line 1833, in response_cost_calculator\n    response_cost = completion_cost(\n                    ^^^^^^^^^^^^^^^^\n  File "/usr/local/lib/python3.12/dist-packages/litellm/cost_calculator.py", line 1743, in completion_cost\n    raise e\n  File "/usr/local/lib/python3.12/dist-packages/litellm/cost_calculator.py", line 1736, in completion_cost\n    raise e\n  File "/usr/local/lib/python3.12/dist-packages/litellm/cost_calculator.py", line 1585, in completion_cost\n    ) = cost_per_token(\n        ^^^^^^^^^^^^^^^\n  File "/usr/local/lib/python3.12/dist-packages/litellm/cost_calculator.py", line 589, in cost_per_token\n    return azure_openai_cost_per_token(\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "/usr/local/lib/python3.12/dist-packages/litellm/llms/azure/cost_calculation.py", line 31, in cost_per_token\n    model_info = get_model_info(model=model, custom_llm_provider="azure")\n                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "/usr/local/lib/python3.12/dist-packages/litellm/utils.py", line 6138, in get_model_info\n    _model_info = _get_model_info_helper(\n                  ^^^^^^^^^^^^^^^^^^^^^^^\n  File "/usr/local/lib/python3.12/dist-packages/litellm/utils.py", line 6051, in _get_model_info_helper\n    raise Exception(\nException: This model isn\'t mapped yet. model=My-Special-Kimi, custom_llm_provider=azure. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json.\n', 'model': 'My-Special-Kimi', 'cache_hit': None, 'custom_llm_provider': 'azure', 'base_model': None, 'call_type': 'completion', 'custom_pricing': False}
# Azure Response
#
# ModelResponse(id='62abdcdef7e24fc686db819afda02e83', created=1780415155, model='Kimi-K2.6', object='chat.completion', system_fingerprint=None, choices=[Choices(finish_reason='stop', index=0, message=Message(content="Hello! I'm doing well, thank you. As an AI, I don't have feelings, but I'm fully operational and ready to help. How can I assist you today?", role='assistant', tool_calls=None, function_call=None, reasoning_content='The user greeted me and asked "how are you?" This is a standard conversational opening. I should respond politely, briefly mention that I\'m an AI without personal feelings (to be accurate), and ask how I can help them today. Keep it friendly and open-ended to invite them to ask whatever they need.\n\nPlan:\n1. Return greeting\n2. State I\'m doing well/functioning well (as an AI)\n3. Ask how I can assist them\n4. Keep tone warm and helpful\n\nNo safety concerns here.', provider_specific_fields={'refusal': None, 'reasoning_content': 'The user greeted me and asked "how are you?" This is a standard conversational opening. I should respond politely, briefly mention that I\'m an AI without personal feelings (to be accurate), and ask how I can help them today. Keep it friendly and open-ended to invite them to ask whatever they need.\n\nPlan:\n1. Return greeting\n2. State I\'m doing well/functioning well (as an AI)\n3. Ask how I can assist them\n4. Keep tone warm and helpful\n\nNo safety concerns here.'}), provider_specific_fields={'content_filter_results': {}})], usage=Usage(completion_tokens=140, prompt_tokens=14, total_tokens=154, completion_tokens_details=None, prompt_tokens_details=PromptTokensDetailsWrapper(audio_tokens=None, cached_tokens=2, text_tokens=None, image_tokens=None, video_tokens=None), audio_prompt_tokens=0), service_tier=None, prompt_filter_results=None)
# DEBUG:LiteLLM:response_cost_failure_debug_information: {'error_str': "This model isn't mapped yet. model=My-Special-Kimi, custom_llm_provider=azure. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json.", 'traceback_str': 'Traceback (most recent call last):\n  File "/usr/local/lib/python3.12/dist-packages/litellm/utils.py", line 5841, in _get_model_info_helper\n    raise ValueError(\nValueError: This model isn\'t mapped yet. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json\n\nDuring handling of the above exception, another exception occurred:\n\nTraceback (most recent call last):\n  File "/usr/local/lib/python3.12/dist-packages/litellm/litellm_core_utils/litellm_logging.py", line 1564, in _response_cost_calculator\n    response_cost = litellm.response_cost_calculator(\n                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "/usr/local/lib/python3.12/dist-packages/litellm/cost_calculator.py", line 1850, in response_cost_calculator\n    raise e\n  File "/usr/local/lib/python3.12/dist-packages/litellm/cost_calculator.py", line 1833, in response_cost_calculator\n    response_cost = completion_cost(\n                    ^^^^^^^^^^^^^^^^\n  File "/usr/local/lib/python3.12/dist-packages/litellm/cost_calculator.py", line 1743, in completion_cost\n    raise e\n  File "/usr/local/lib/python3.12/dist-packages/litellm/cost_calculator.py", line 1736, in completion_cost\n    raise e\n  File "/usr/local/lib/python3.12/dist-packages/litellm/cost_calculator.py", line 1585, in completion_cost\n    ) = cost_per_token(\n        ^^^^^^^^^^^^^^^\n  File "/usr/local/lib/python3.12/dist-packages/litellm/cost_calculator.py", line 589, in cost_per_token\n    return azure_openai_cost_per_token(\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "/usr/local/lib/python3.12/dist-packages/litellm/llms/azure/cost_calculation.py", line 31, in cost_per_token\n    model_info = get_model_info(model=model, custom_llm_provider="azure")\n                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "/usr/local/lib/python3.12/dist-packages/litellm/utils.py", line 6138, in get_model_info\n    _model_info = _get_model_info_helper(\n                  ^^^^^^^^^^^^^^^^^^^^^^^\n  File "/usr/local/lib/python3.12/dist-packages/litellm/utils.py", line 6051, in _get_model_info_helper\n    raise Exception(\nException: This model isn\'t mapped yet. model=My-Special-Kimi, custom_llm_provider=azure. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json.\n', 'model': 'My-Special-Kimi', 'cache_hit': None, 'custom_llm_provider': 'azure', 'base_model': None, 'call_type': 'completion', 'custom_pricing': False}
# 15:45:56 - LiteLLM:DEBUG: utils.py:5745 - checking potential_model_names in litellm.model_cost: {'split_model': 'Kimi-K2.6', 'combined_model_name': 'azure/Kimi-K2.6', 'stripped_model_name': 'Kimi-K2.6', 'combined_stripped_model_name': 'azure/Kimi-K2.6', 'custom_llm_provider': 'azure'}
# DEBUG:LiteLLM:checking potential_model_names in litellm.model_cost: {'split_model': 'Kimi-K2.6', 'combined_model_name': 'azure/Kimi-K2.6', 'stripped_model_name': 'Kimi-K2.6', 'combined_stripped_model_name': 'azure/Kimi-K2.6', 'custom_llm_provider': 'azure'}

# %% [markdown]
# ### *Foundry OpenAI*

# %%
from litellm import completion
from google.colab import userdata

response = completion(
    api_key=userdata.get('AZURE_API_KEY'),
    api_base="https://openhands-test.services.ai.azure.com/",
    model = "azure/my-special-gpt-5.2",
    messages = [{ "content": "Hello, how are you?","role": "user"}]
)
print("Azure Response\n")
print(response)
# Out:
# 15:47:02 - LiteLLM:DEBUG: utils.py:485 -
#
# DEBUG:LiteLLM:
#
# 15:47:02 - LiteLLM:DEBUG: utils.py:485 - Request to litellm:
# DEBUG:LiteLLM:Request to litellm:
# 15:47:02 - LiteLLM:DEBUG: utils.py:485 - litellm.completion(REDACTED', api_base='https://openhands-test.services.ai.azure.com/', model='azure/my-special-gpt-5.2', messages=[{'content': 'Hello, how are you?', 'role': 'user'}])
# DEBUG:LiteLLM:litellm.completion(REDACTED', api_base='https://openhands-test.services.ai.azure.com/', model='azure/my-special-gpt-5.2', messages=[{'content': 'Hello, how are you?', 'role': 'user'}])
# 15:47:02 - LiteLLM:DEBUG: utils.py:485 -
#
# DEBUG:LiteLLM:
#
# 15:47:02 - LiteLLM:DEBUG: utils.py:1011 - Removing thought signatures from tool call IDs for non-Gemini model
# DEBUG:LiteLLM:Removing thought signatures from tool call IDs for non-Gemini model
# 15:47:02 - LiteLLM:DEBUG: litellm_logging.py:563 - self.optional_params: {}
# DEBUG:LiteLLM:self.optional_params: {}
# 15:47:02 - LiteLLM:DEBUG: utils.py:485 - SYNC kwargs[caching]: False; litellm.cache: None; kwargs.get('cache')['no-cache']: False
# DEBUG:LiteLLM:SYNC kwargs[caching]: False; litellm.cache: None; kwargs.get('cache')['no-cache']: False
# 15:47:02 - LiteLLM:DEBUG: utils.py:5745 - checking potential_model_names in litellm.model_cost: {'split_model': 'my-special-gpt-5.2', 'combined_model_name': 'azure/my-special-gpt-5.2', 'stripped_model_name': 'my-special-gpt-5.2', 'combined_stripped_model_name': 'azure/my-special-gpt-5.2', 'custom_llm_provider': 'azure'}
# DEBUG:LiteLLM:checking potential_model_names in litellm.model_cost: {'split_model': 'my-special-gpt-5.2', 'combined_model_name': 'azure/my-special-gpt-5.2', 'stripped_model_name': 'my-special-gpt-5.2', 'combined_stripped_model_name': 'azure/my-special-gpt-5.2', 'custom_llm_provider': 'azure'}
# 15:47:02 - LiteLLM:DEBUG: utils.py:6050 - Error getting model info: This model isn't mapped yet. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json
# DEBUG:LiteLLM:Error getting model info: This model isn't mapped yet. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json
# 15:47:02 - LiteLLM:DEBUG: main.py:985 - Error getting model info: This model isn't mapped yet. model=my-special-gpt-5.2, custom_llm_provider=azure. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json.
# DEBUG:LiteLLM:Error getting model info: This model isn't mapped yet. model=my-special-gpt-5.2, custom_llm_provider=azure. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json.
# 15:47:02 - LiteLLM:DEBUG: utils.py:2634 - Model not found or error in checking supports_tool_choice support. You passed model=my-special-gpt-5.2, custom_llm_provider=None. Error: litellm.BadRequestError: LLM Provider NOT provided. Pass in the LLM provider you are trying to call. You passed model=my-special-gpt-5.2
#  Pass model as E.g. For 'Huggingface' inference endpoints pass in `completion(model='huggingface/starcoder',..)` Learn more: https://docs.litellm.ai/docs/providers
# DEBUG:LiteLLM:Model not found or error in checking supports_tool_choice support. You passed model=my-special-gpt-5.2, custom_llm_provider=None. Error: litellm.BadRequestError: LLM Provider NOT provided. Pass in the LLM provider you are trying to call. You passed model=my-special-gpt-5.2
#  Pass model as E.g. For 'Huggingface' inference endpoints pass in `completion(model='huggingface/starcoder',..)` Learn more: https://docs.litellm.ai/docs/providers
# 15:47:02 - LiteLLM:DEBUG: utils.py:5745 - checking potential_model_names in litellm.model_cost: {'split_model': 'my-special-gpt-5.2', 'combined_model_name': 'azure/my-special-gpt-5.2', 'stripped_model_name': 'my-special-gpt-5.2', 'combined_stripped_model_name': 'azure/my-special-gpt-5.2', 'custom_llm_provider': 'azure'}
# DEBUG:LiteLLM:checking potential_model_names in litellm.model_cost: {'split_model': 'my-special-gpt-5.2', 'combined_model_name': 'azure/my-special-gpt-5.2', 'stripped_model_name': 'my-special-gpt-5.2', 'combined_stripped_model_name': 'azure/my-special-gpt-5.2', 'custom_llm_provider': 'azure'}
# 15:47:02 - LiteLLM:DEBUG: utils.py:6050 - Error getting model info: This model isn't mapped yet. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json
# DEBUG:LiteLLM:Error getting model info: This model isn't mapped yet. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json
# 15:47:02 - LiteLLM:DEBUG: utils.py:2634 - Model not found or error in checking supports_none_reasoning_effort support. You passed model=my-special-gpt-5.2, custom_llm_provider=azure. Error: This model isn't mapped yet. model=my-special-gpt-5.2, custom_llm_provider=azure. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json.
# DEBUG:LiteLLM:Model not found or error in checking supports_none_reasoning_effort support. You passed model=my-special-gpt-5.2, custom_llm_provider=azure. Error: This model isn't mapped yet. model=my-special-gpt-5.2, custom_llm_provider=azure. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json.
# 15:47:02 - LiteLLM:DEBUG: utils.py:5745 - checking potential_model_names in litellm.model_cost: {'split_model': 'my-special-gpt-5.2', 'combined_model_name': 'azure/my-special-gpt-5.2', 'stripped_model_name': 'my-special-gpt-5.2', 'combined_stripped_model_name': 'azure/my-special-gpt-5.2', 'custom_llm_provider': 'azure'}
# DEBUG:LiteLLM:checking potential_model_names in litellm.model_cost: {'split_model': 'my-special-gpt-5.2', 'combined_model_name': 'azure/my-special-gpt-5.2', 'stripped_model_name': 'my-special-gpt-5.2', 'combined_stripped_model_name': 'azure/my-special-gpt-5.2', 'custom_llm_provider': 'azure'}
# 15:47:02 - LiteLLM:DEBUG: utils.py:6050 - Error getting model info: This model isn't mapped yet. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json
# DEBUG:LiteLLM:Error getting model info: This model isn't mapped yet. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json
# 15:47:02 - LiteLLM:DEBUG: utils.py:2634 - Model not found or error in checking supports_none_reasoning_effort support. You passed model=my-special-gpt-5.2, custom_llm_provider=azure. Error: This model isn't mapped yet. model=my-special-gpt-5.2, custom_llm_provider=azure. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json.
# DEBUG:LiteLLM:Model not found or error in checking supports_none_reasoning_effort support. You passed model=my-special-gpt-5.2, custom_llm_provider=azure. Error: This model isn't mapped yet. model=my-special-gpt-5.2, custom_llm_provider=azure. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json.
# 15:47:02 - LiteLLM:INFO: utils.py:4083 -
# LiteLLM completion() model= my-special-gpt-5.2; provider = azure
# INFO:LiteLLM:
# LiteLLM completion() model= my-special-gpt-5.2; provider = azure
# 15:47:02 - LiteLLM:DEBUG: utils.py:4086 -
# LiteLLM: Params passed to completion() {'model': 'my-special-gpt-5.2', 'functions': None, 'function_call': None, 'temperature': None, 'top_p': None, 'n': None, 'stream': None, 'stream_options': None, 'stop': None, 'max_tokens': None, 'max_completion_tokens': None, 'modalities': None, 'prediction': None, 'audio': None, 'presence_penalty': None, 'frequency_penalty': None, 'logit_bias': None, 'user': None, 'custom_llm_provider': 'azure', 'response_format': None, 'seed': None, 'tools': None, 'tool_choice': None, 'max_retries': None, 'logprobs': None, 'top_logprobs': None, 'extra_headers': None, 'api_version': None, 'parallel_tool_calls': None, 'drop_params': None, 'allowed_openai_params': None, 'reasoning_effort': None, 'verbosity': None, 'additional_drop_params': None, 'messages': [{'content': 'Hello, how are you?', 'role': 'user'}], 'thinking': None, 'web_search_options': None, 'safety_identifier': None, 'service_tier': None}
# DEBUG:LiteLLM:
# LiteLLM: Params passed to completion() {'model': 'my-special-gpt-5.2', 'functions': None, 'function_call': None, 'temperature': None, 'top_p': None, 'n': None, 'stream': None, 'stream_options': None, 'stop': None, 'max_tokens': None, 'max_completion_tokens': None, 'modalities': None, 'prediction': None, 'audio': None, 'presence_penalty': None, 'frequency_penalty': None, 'logit_bias': None, 'user': None, 'custom_llm_provider': 'azure', 'response_format': None, 'seed': None, 'tools': None, 'tool_choice': None, 'max_retries': None, 'logprobs': None, 'top_logprobs': None, 'extra_headers': None, 'api_version': None, 'parallel_tool_calls': None, 'drop_params': None, 'allowed_openai_params': None, 'reasoning_effort': None, 'verbosity': None, 'additional_drop_params': None, 'messages': [{'content': 'Hello, how are you?', 'role': 'user'}], 'thinking': None, 'web_search_options': None, 'safety_identifier': None, 'service_tier': None}
# 15:47:02 - LiteLLM:DEBUG: utils.py:4089 -
# LiteLLM: Non-Default params passed to completion() {}
# DEBUG:LiteLLM:
# LiteLLM: Non-Default params passed to completion() {}
# 15:47:02 - LiteLLM:DEBUG: utils.py:5745 - checking potential_model_names in litellm.model_cost: {'split_model': 'my-special-gpt-5.2', 'combined_model_name': 'azure/my-special-gpt-5.2', 'stripped_model_name': 'my-special-gpt-5.2', 'combined_stripped_model_name': 'azure/my-special-gpt-5.2', 'custom_llm_provider': 'azure'}
# DEBUG:LiteLLM:checking potential_model_names in litellm.model_cost: {'split_model': 'my-special-gpt-5.2', 'combined_model_name': 'azure/my-special-gpt-5.2', 'stripped_model_name': 'my-special-gpt-5.2', 'combined_stripped_model_name': 'azure/my-special-gpt-5.2', 'custom_llm_provider': 'azure'}
# 15:47:02 - LiteLLM:DEBUG: utils.py:6050 - Error getting model info: This model isn't mapped yet. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json
# DEBUG:LiteLLM:Error getting model info: This model isn't mapped yet. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json
# 15:47:02 - LiteLLM:DEBUG: utils.py:2634 - Model not found or error in checking supports_none_reasoning_effort support. You passed model=my-special-gpt-5.2, custom_llm_provider=azure. Error: This model isn't mapped yet. model=my-special-gpt-5.2, custom_llm_provider=azure. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json.
# DEBUG:LiteLLM:Model not found or error in checking supports_none_reasoning_effort support. You passed model=my-special-gpt-5.2, custom_llm_provider=azure. Error: This model isn't mapped yet. model=my-special-gpt-5.2, custom_llm_provider=azure. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json.
# 15:47:02 - LiteLLM:DEBUG: utils.py:5745 - checking potential_model_names in litellm.model_cost: {'split_model': 'my-special-gpt-5.2', 'combined_model_name': 'azure/my-special-gpt-5.2', 'stripped_model_name': 'my-special-gpt-5.2', 'combined_stripped_model_name': 'azure/my-special-gpt-5.2', 'custom_llm_provider': 'azure'}
# DEBUG:LiteLLM:checking potential_model_names in litellm.model_cost: {'split_model': 'my-special-gpt-5.2', 'combined_model_name': 'azure/my-special-gpt-5.2', 'stripped_model_name': 'my-special-gpt-5.2', 'combined_stripped_model_name': 'azure/my-special-gpt-5.2', 'custom_llm_provider': 'azure'}
# 15:47:02 - LiteLLM:DEBUG: utils.py:6050 - Error getting model info: This model isn't mapped yet. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json
# DEBUG:LiteLLM:Error getting model info: This model isn't mapped yet. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json
# 15:47:02 - LiteLLM:DEBUG: utils.py:2634 - Model not found or error in checking supports_none_reasoning_effort support. You passed model=my-special-gpt-5.2, custom_llm_provider=azure. Error: This model isn't mapped yet. model=my-special-gpt-5.2, custom_llm_provider=azure. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json.
# DEBUG:LiteLLM:Model not found or error in checking supports_none_reasoning_effort support. You passed model=my-special-gpt-5.2, custom_llm_provider=azure. Error: This model isn't mapped yet. model=my-special-gpt-5.2, custom_llm_provider=azure. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json.
# 15:47:02 - LiteLLM:DEBUG: utils.py:2634 - Model not found or error in checking supports_tool_choice support. You passed model=my-special-gpt-5.2, custom_llm_provider=None. Error: litellm.BadRequestError: LLM Provider NOT provided. Pass in the LLM provider you are trying to call. You passed model=my-special-gpt-5.2
#  Pass model as E.g. For 'Huggingface' inference endpoints pass in `completion(model='huggingface/starcoder',..)` Learn more: https://docs.litellm.ai/docs/providers
# DEBUG:LiteLLM:Model not found or error in checking supports_tool_choice support. You passed model=my-special-gpt-5.2, custom_llm_provider=None. Error: litellm.BadRequestError: LLM Provider NOT provided. Pass in the LLM provider you are trying to call. You passed model=my-special-gpt-5.2
#  Pass model as E.g. For 'Huggingface' inference endpoints pass in `completion(model='huggingface/starcoder',..)` Learn more: https://docs.litellm.ai/docs/providers
# 15:47:02 - LiteLLM:DEBUG: utils.py:5745 - checking potential_model_names in litellm.model_cost: {'split_model': 'my-special-gpt-5.2', 'combined_model_name': 'azure/my-special-gpt-5.2', 'stripped_model_name': 'my-special-gpt-5.2', 'combined_stripped_model_name': 'azure/my-special-gpt-5.2', 'custom_llm_provider': 'azure'}
# DEBUG:LiteLLM:checking potential_model_names in litellm.model_cost: {'split_model': 'my-special-gpt-5.2', 'combined_model_name': 'azure/my-special-gpt-5.2', 'stripped_model_name': 'my-special-gpt-5.2', 'combined_stripped_model_name': 'azure/my-special-gpt-5.2', 'custom_llm_provider': 'azure'}
# 15:47:02 - LiteLLM:DEBUG: utils.py:6050 - Error getting model info: This model isn't mapped yet. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json
# DEBUG:LiteLLM:Error getting model info: This model isn't mapped yet. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json
# 15:47:02 - LiteLLM:DEBUG: utils.py:2634 - Model not found or error in checking supports_none_reasoning_effort support. You passed model=my-special-gpt-5.2, custom_llm_provider=azure. Error: This model isn't mapped yet. model=my-special-gpt-5.2, custom_llm_provider=azure. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json.
# DEBUG:LiteLLM:Model not found or error in checking supports_none_reasoning_effort support. You passed model=my-special-gpt-5.2, custom_llm_provider=azure. Error: This model isn't mapped yet. model=my-special-gpt-5.2, custom_llm_provider=azure. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json.
# 15:47:02 - LiteLLM:DEBUG: utils.py:5745 - checking potential_model_names in litellm.model_cost: {'split_model': 'my-special-gpt-5.2', 'combined_model_name': 'azure/my-special-gpt-5.2', 'stripped_model_name': 'my-special-gpt-5.2', 'combined_stripped_model_name': 'azure/my-special-gpt-5.2', 'custom_llm_provider': 'azure'}
# DEBUG:LiteLLM:checking potential_model_names in litellm.model_cost: {'split_model': 'my-special-gpt-5.2', 'combined_model_name': 'azure/my-special-gpt-5.2', 'stripped_model_name': 'my-special-gpt-5.2', 'combined_stripped_model_name': 'azure/my-special-gpt-5.2', 'custom_llm_provider': 'azure'}
# 15:47:02 - LiteLLM:DEBUG: utils.py:6050 - Error getting model info: This model isn't mapped yet. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json
# DEBUG:LiteLLM:Error getting model info: This model isn't mapped yet. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json
# 15:47:02 - LiteLLM:DEBUG: utils.py:2634 - Model not found or error in checking supports_none_reasoning_effort support. You passed model=my-special-gpt-5.2, custom_llm_provider=azure. Error: This model isn't mapped yet. model=my-special-gpt-5.2, custom_llm_provider=azure. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json.
# DEBUG:LiteLLM:Model not found or error in checking supports_none_reasoning_effort support. You passed model=my-special-gpt-5.2, custom_llm_provider=azure. Error: This model isn't mapped yet. model=my-special-gpt-5.2, custom_llm_provider=azure. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json.
# 15:47:02 - LiteLLM:DEBUG: utils.py:485 - Final returned optional params: {'extra_body': {}}
# DEBUG:LiteLLM:Final returned optional params: {'extra_body': {}}
# 15:47:02 - LiteLLM:DEBUG: litellm_logging.py:563 - self.optional_params: {'extra_body': {}}
# DEBUG:LiteLLM:self.optional_params: {'extra_body': {}}
# 15:47:02 - LiteLLM:DEBUG: utils.py:5745 - checking potential_model_names in litellm.model_cost: {'split_model': 'my-special-gpt-5.2', 'combined_model_name': 'azure/my-special-gpt-5.2', 'stripped_model_name': 'my-special-gpt-5.2', 'combined_stripped_model_name': 'azure/my-special-gpt-5.2', 'custom_llm_provider': 'azure'}
# DEBUG:LiteLLM:checking potential_model_names in litellm.model_cost: {'split_model': 'my-special-gpt-5.2', 'combined_model_name': 'azure/my-special-gpt-5.2', 'stripped_model_name': 'my-special-gpt-5.2', 'combined_stripped_model_name': 'azure/my-special-gpt-5.2', 'custom_llm_provider': 'azure'}
# 15:47:02 - LiteLLM:DEBUG: utils.py:6050 - Error getting model info: This model isn't mapped yet. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json
# DEBUG:LiteLLM:Error getting model info: This model isn't mapped yet. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json
# 15:47:02 - LiteLLM:DEBUG: main.py:985 - Error getting model info: This model isn't mapped yet. model=my-special-gpt-5.2, custom_llm_provider=azure. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json.
# DEBUG:LiteLLM:Error getting model info: This model isn't mapped yet. model=my-special-gpt-5.2, custom_llm_provider=azure. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json.
# Provider List: https://docs.litellm.ai/docs/providers
#
#
# Provider List: https://docs.litellm.ai/docs/providers
# 15:47:02 - LiteLLM:DEBUG: litellm_logging.py:1170 -
#
# POST Request Sent from LiteLLM:
# curl -X POST \
# https://openhands-test.services.ai.azure.com/ \
# -H 'REDACTED' -H 'azure_ad_token: None' \
# -d '{'model': 'my-special-gpt-5.2', 'messages': [{'content': 'Hello, how are you?', 'role': 'user'}]}'
#
#
# DEBUG:LiteLLM:
#
# POST Request Sent from LiteLLM:
# curl -X POST \
# https://openhands-test.services.ai.azure.com/ \
# -H 'REDACTED' -H 'azure_ad_token: None' \
# -d '{'model': 'my-special-gpt-5.2', 'messages': [{'content': 'Hello, how are you?', 'role': 'user'}]}'
#
#
# 15:47:04 - LiteLLM:DEBUG: litellm_logging.py:1243 - RAW RESPONSE:
# {"id": "chatcmpl-DmLcVqhvvjJWWsoW5WWRUQJalOnFx", "choices": [{"finish_reason": "stop", "index": 0, "logprobs": null, "message": {"content": "Hello! I\u2019m here and ready to help. What would you like to work on today?", "refusal": null, "role": "assistant", "annotations": [], "audio": null, "function_call": null, "tool_calls": null}}], "created": 1780415223, "model": "gpt-5.2-2025-12-11", "object": "chat.completion", "service_tier": "default", "system_fingerprint": null, "usage": {"completion_tokens": 23, "prompt_tokens": 12, "total_tokens": 35, "completion_tokens_details": {"accepted_prediction_tokens": 0, "audio_tokens": 0, "reasoning_tokens": 0, "rejected_prediction_tokens": 0}, "prompt_tokens_details": {"audio_tokens": 0, "cached_tokens": 0}, "latency_checkpoint": {"engine_tbt_ms": 11, "engine_ttft_ms": 63, "engine_ttlt_ms": 320, "pre_inference_ms": 111, "service_tbt_ms": 11, "service_ttft_ms": 271, "service_ttlt_ms": 521, "total_duration_ms": 420, "user_visible_ttft_ms": 160}}}
#
#
# DEBUG:LiteLLM:RAW RESPONSE:
# {"id": "chatcmpl-DmLcVqhvvjJWWsoW5WWRUQJalOnFx", "choices": [{"finish_reason": "stop", "index": 0, "logprobs": null, "message": {"content": "Hello! I\u2019m here and ready to help. What would you like to work on today?", "refusal": null, "role": "assistant", "annotations": [], "audio": null, "function_call": null, "tool_calls": null}}], "created": 1780415223, "model": "gpt-5.2-2025-12-11", "object": "chat.completion", "service_tier": "default", "system_fingerprint": null, "usage": {"completion_tokens": 23, "prompt_tokens": 12, "total_tokens": 35, "completion_tokens_details": {"accepted_prediction_tokens": 0, "audio_tokens": 0, "reasoning_tokens": 0, "rejected_prediction_tokens": 0}, "prompt_tokens_details": {"audio_tokens": 0, "cached_tokens": 0}, "latency_checkpoint": {"engine_tbt_ms": 11, "engine_ttft_ms": 63, "engine_ttlt_ms": 320, "pre_inference_ms": 111, "service_tbt_ms": 11, "service_ttft_ms": 271, "service_ttlt_ms": 521, "total_duration_ms": 420, "user_visible_ttft_ms": 160}}}
#
#
# 15:47:04 - LiteLLM:INFO: utils.py:1656 - Wrapper: Completed Call, calling success_handler
# INFO:LiteLLM:Wrapper: Completed Call, calling success_handler
# 15:47:04 - LiteLLM:DEBUG: cost_calculator.py:1212 - selected model name for cost calculation: azure/gpt-5.2-2025-12-11
# DEBUG:LiteLLM:selected model name for cost calculation: azure/gpt-5.2-2025-12-11
# 15:47:04 - LiteLLM:DEBUG: litellm_logging.py:2017 - Logging Details LiteLLM-Success Call: Cache_hit=None
# DEBUG:LiteLLM:Logging Details LiteLLM-Success Call: Cache_hit=None
# 15:47:04 - LiteLLM:DEBUG: litellm_logging.py:1568 - response_cost: 0.00034300000000000004
# DEBUG:LiteLLM:response_cost: 0.00034300000000000004
# 15:47:04 - LiteLLM:DEBUG: cost_calculator.py:1212 - selected model name for cost calculation: azure/gpt-5.2-2025-12-11
# DEBUG:LiteLLM:selected model name for cost calculation: azure/gpt-5.2-2025-12-11
# Azure Response
#
# ModelResponse(id='chatcmpl-DmLcVqhvvjJWWsoW5WWRUQJalOnFx', created=1780415223, model='gpt-5.2-2025-12-11', object='chat.completion', system_fingerprint=None, choices=[Choices(finish_reason='stop', index=0, message=Message(content='Hello! I’m here and ready to help. What would you like to work on today?', role='assistant', tool_calls=None, function_call=None, provider_specific_fields={'refusal': None}, annotations=[]), provider_specific_fields={})], usage=Usage(completion_tokens=23, prompt_tokens=12, total_tokens=35, completion_tokens_details=CompletionTokensDetailsWrapper(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0, text_tokens=None, image_tokens=None, video_tokens=None), prompt_tokens_details=PromptTokensDetailsWrapper(audio_tokens=0, cached_tokens=0, text_tokens=None, image_tokens=None, video_tokens=None), latency_checkpoint={'engine_tbt_ms': 11, 'engine_ttft_ms': 63, 'engine_ttlt_ms': 320, 'pre_inference_ms': 111, 'service_tbt_ms': 11, 'service_ttft_ms': 271, 'service_ttlt_ms': 521, 'total_duration_ms': 420, 'user_visible_ttft_ms': 160}), service_tier='default')
# 15:47:04 - LiteLLM:DEBUG: litellm_logging.py:1568 - response_cost: 0.00034300000000000004
# DEBUG:LiteLLM:response_cost: 0.00034300000000000004

# %% [markdown]
# ### *Anthropic*

# %%
from litellm import completion
from google.colab import userdata

response = completion(
    api_base="https://api.anthropic.com",
    api_key=userdata.get('ANTHROPIC_API_KEY'),
    model = "anthropic/claude-sonnet-4-5",
    messages = [{ "content": "Hello, how are you?","role": "user"}]
)
print("Anthropic Response\n")
print(response)
# Out:
# 15:48:21 - LiteLLM:DEBUG: utils.py:485 -
#
# DEBUG:LiteLLM:
#
# 15:48:21 - LiteLLM:DEBUG: utils.py:485 - Request to litellm:
# DEBUG:LiteLLM:Request to litellm:
# 15:48:21 - LiteLLM:DEBUG: utils.py:485 - litellm.completion(api_base='https://api.anthropic.com', REDACTED', model='anthropic/claude-sonnet-4-5', messages=[{'content': 'Hello, how are you?', 'role': 'user'}])
# DEBUG:LiteLLM:litellm.completion(api_base='https://api.anthropic.com', REDACTED', model='anthropic/claude-sonnet-4-5', messages=[{'content': 'Hello, how are you?', 'role': 'user'}])
# 15:48:21 - LiteLLM:DEBUG: utils.py:485 -
#
# DEBUG:LiteLLM:
#
# 15:48:21 - LiteLLM:DEBUG: utils.py:1011 - Removing thought signatures from tool call IDs for non-Gemini model
# DEBUG:LiteLLM:Removing thought signatures from tool call IDs for non-Gemini model
# 15:48:21 - LiteLLM:DEBUG: litellm_logging.py:563 - self.optional_params: {}
# DEBUG:LiteLLM:self.optional_params: {}
# 15:48:21 - LiteLLM:DEBUG: utils.py:485 - SYNC kwargs[caching]: False; litellm.cache: None; kwargs.get('cache')['no-cache']: False
# DEBUG:LiteLLM:SYNC kwargs[caching]: False; litellm.cache: None; kwargs.get('cache')['no-cache']: False
# 15:48:21 - LiteLLM:DEBUG: utils.py:5745 - checking potential_model_names in litellm.model_cost: {'split_model': 'claude-sonnet-4-5', 'combined_model_name': 'anthropic/claude-sonnet-4-5', 'stripped_model_name': 'claude-sonnet-4-5', 'combined_stripped_model_name': 'anthropic/claude-sonnet-4-5', 'custom_llm_provider': 'anthropic'}
# DEBUG:LiteLLM:checking potential_model_names in litellm.model_cost: {'split_model': 'claude-sonnet-4-5', 'combined_model_name': 'anthropic/claude-sonnet-4-5', 'stripped_model_name': 'claude-sonnet-4-5', 'combined_stripped_model_name': 'anthropic/claude-sonnet-4-5', 'custom_llm_provider': 'anthropic'}
# 15:48:21 - LiteLLM:DEBUG: utils.py:5745 - checking potential_model_names in litellm.model_cost: {'split_model': 'claude-sonnet-4-5', 'combined_model_name': 'anthropic/claude-sonnet-4-5', 'stripped_model_name': 'claude-sonnet-4-5', 'combined_stripped_model_name': 'anthropic/claude-sonnet-4-5', 'custom_llm_provider': 'anthropic'}
# DEBUG:LiteLLM:checking potential_model_names in litellm.model_cost: {'split_model': 'claude-sonnet-4-5', 'combined_model_name': 'anthropic/claude-sonnet-4-5', 'stripped_model_name': 'claude-sonnet-4-5', 'combined_stripped_model_name': 'anthropic/claude-sonnet-4-5', 'custom_llm_provider': 'anthropic'}
# 15:48:21 - LiteLLM:INFO: utils.py:4083 -
# LiteLLM completion() model= claude-sonnet-4-5; provider = anthropic
# INFO:LiteLLM:
# LiteLLM completion() model= claude-sonnet-4-5; provider = anthropic
# 15:48:21 - LiteLLM:DEBUG: utils.py:4086 -
# LiteLLM: Params passed to completion() {'model': 'claude-sonnet-4-5', 'functions': None, 'function_call': None, 'temperature': None, 'top_p': None, 'n': None, 'stream': None, 'stream_options': None, 'stop': None, 'max_tokens': None, 'max_completion_tokens': None, 'modalities': None, 'prediction': None, 'audio': None, 'presence_penalty': None, 'frequency_penalty': None, 'logit_bias': None, 'user': None, 'custom_llm_provider': 'anthropic', 'response_format': None, 'seed': None, 'tools': None, 'tool_choice': None, 'max_retries': None, 'logprobs': None, 'top_logprobs': None, 'extra_headers': None, 'api_version': None, 'parallel_tool_calls': None, 'drop_params': None, 'allowed_openai_params': None, 'reasoning_effort': None, 'verbosity': None, 'additional_drop_params': None, 'messages': [{'content': 'Hello, how are you?', 'role': 'user'}], 'thinking': None, 'web_search_options': None, 'safety_identifier': None, 'service_tier': None}
# DEBUG:LiteLLM:
# LiteLLM: Params passed to completion() {'model': 'claude-sonnet-4-5', 'functions': None, 'function_call': None, 'temperature': None, 'top_p': None, 'n': None, 'stream': None, 'stream_options': None, 'stop': None, 'max_tokens': None, 'max_completion_tokens': None, 'modalities': None, 'prediction': None, 'audio': None, 'presence_penalty': None, 'frequency_penalty': None, 'logit_bias': None, 'user': None, 'custom_llm_provider': 'anthropic', 'response_format': None, 'seed': None, 'tools': None, 'tool_choice': None, 'max_retries': None, 'logprobs': None, 'top_logprobs': None, 'extra_headers': None, 'api_version': None, 'parallel_tool_calls': None, 'drop_params': None, 'allowed_openai_params': None, 'reasoning_effort': None, 'verbosity': None, 'additional_drop_params': None, 'messages': [{'content': 'Hello, how are you?', 'role': 'user'}], 'thinking': None, 'web_search_options': None, 'safety_identifier': None, 'service_tier': None}
# 15:48:21 - LiteLLM:DEBUG: utils.py:4089 -
# LiteLLM: Non-Default params passed to completion() {}
# DEBUG:LiteLLM:
# LiteLLM: Non-Default params passed to completion() {}
# 15:48:21 - LiteLLM:DEBUG: utils.py:485 - Final returned optional params: {}
# DEBUG:LiteLLM:Final returned optional params: {}
# 15:48:21 - LiteLLM:DEBUG: litellm_logging.py:563 - self.optional_params: {}
# DEBUG:LiteLLM:self.optional_params: {}
# 15:48:21 - LiteLLM:DEBUG: utils.py:5745 - checking potential_model_names in litellm.model_cost: {'split_model': 'claude-sonnet-4-5', 'combined_model_name': 'anthropic/claude-sonnet-4-5', 'stripped_model_name': 'claude-sonnet-4-5', 'combined_stripped_model_name': 'anthropic/claude-sonnet-4-5', 'custom_llm_provider': 'anthropic'}
# DEBUG:LiteLLM:checking potential_model_names in litellm.model_cost: {'split_model': 'claude-sonnet-4-5', 'combined_model_name': 'anthropic/claude-sonnet-4-5', 'stripped_model_name': 'claude-sonnet-4-5', 'combined_stripped_model_name': 'anthropic/claude-sonnet-4-5', 'custom_llm_provider': 'anthropic'}
# 15:48:21 - LiteLLM:DEBUG: utils.py:5745 - checking potential_model_names in litellm.model_cost: {'split_model': 'claude-sonnet-4-5', 'combined_model_name': 'anthropic/claude-sonnet-4-5', 'stripped_model_name': 'claude-sonnet-4-5', 'combined_stripped_model_name': 'anthropic/claude-sonnet-4-5', 'custom_llm_provider': 'anthropic'}
# DEBUG:LiteLLM:checking potential_model_names in litellm.model_cost: {'split_model': 'claude-sonnet-4-5', 'combined_model_name': 'anthropic/claude-sonnet-4-5', 'stripped_model_name': 'claude-sonnet-4-5', 'combined_stripped_model_name': 'anthropic/claude-sonnet-4-5', 'custom_llm_provider': 'anthropic'}
# 15:48:21 - LiteLLM:DEBUG: litellm_logging.py:1170 -
#
# POST Request Sent from LiteLLM:
# curl -X POST \
# https://api.anthropic.com/v1/messages \
# -H 'anthropic-version: 2023-06-01' -H 'accept: application/json' -H 'content-type: application/json' -H 'REDACTED' \
# -d '{'model': 'claude-sonnet-4-5', 'messages': [{'role': 'user', 'content': [{'type': 'text', 'text': 'Hello, how are you?'}]}], 'max_tokens': 64000}'
#
#
# DEBUG:LiteLLM:
#
# POST Request Sent from LiteLLM:
# curl -X POST \
# https://api.anthropic.com/v1/messages \
# -H 'anthropic-version: 2023-06-01' -H 'accept: application/json' -H 'content-type: application/json' -H 'REDACTED' \
# -d '{'model': 'claude-sonnet-4-5', 'messages': [{'role': 'user', 'content': [{'type': 'text', 'text': 'Hello, how are you?'}]}], 'max_tokens': 64000}'
#
#
# 15:48:21 - LiteLLM:DEBUG: main.py:7434 - _is_function_call: False
# DEBUG:LiteLLM:_is_function_call: False
# 15:48:23 - LiteLLM:DEBUG: litellm_logging.py:1243 - RAW RESPONSE:
# {"model":"claude-sonnet-4-5-20250929","id":"msg_01DELwMCSspBQmWJgDtxYHhc","type":"message","role":"assistant","content":[{"type":"text","text":"Hello! I'm doing well, thank you for asking. How are you doing today? Is there something I can help you with?"}],"stop_reason":"end_turn","stop_sequence":null,"stop_details":null,"usage":{"input_tokens":13,"cache_creation_input_tokens":0,"cache_read_input_tokens":0,"cache_creation":{"ephemeral_5m_input_tokens":0,"ephemeral_1h_input_tokens":0},"output_tokens":30,"service_tier":"standard","inference_geo":"not_available"}}
#
#
# DEBUG:LiteLLM:RAW RESPONSE:
# {"model":"claude-sonnet-4-5-20250929","id":"msg_01DELwMCSspBQmWJgDtxYHhc","type":"message","role":"assistant","content":[{"type":"text","text":"Hello! I'm doing well, thank you for asking. How are you doing today? Is there something I can help you with?"}],"stop_reason":"end_turn","stop_sequence":null,"stop_details":null,"usage":{"input_tokens":13,"cache_creation_input_tokens":0,"cache_read_input_tokens":0,"cache_creation":{"ephemeral_5m_input_tokens":0,"ephemeral_1h_input_tokens":0},"output_tokens":30,"service_tier":"standard","inference_geo":"not_available"}}
#
#
# 15:48:23 - LiteLLM:INFO: utils.py:1656 - Wrapper: Completed Call, calling success_handler
# INFO:LiteLLM:Wrapper: Completed Call, calling success_handler
# 15:48:23 - LiteLLM:DEBUG: cost_calculator.py:1212 - selected model name for cost calculation: anthropic/claude-sonnet-4-5-20250929
# DEBUG:LiteLLM:selected model name for cost calculation: anthropic/claude-sonnet-4-5-20250929
# 15:48:23 - LiteLLM:DEBUG: litellm_logging.py:2017 - Logging Details LiteLLM-Success Call: Cache_hit=None
# 15:48:23 - LiteLLM:DEBUG: litellm_logging.py:1568 - response_cost: 0.000489
# DEBUG:LiteLLM:Logging Details LiteLLM-Success Call: Cache_hit=None
# DEBUG:LiteLLM:response_cost: 0.000489
# 15:48:23 - LiteLLM:DEBUG: cost_calculator.py:1212 - selected model name for cost calculation: anthropic/claude-sonnet-4-5-20250929
# Anthropic Response
#
# ModelResponse(id='chatcmpl-488da19f-3a5e-43c4-b58b-beba5e4effef', created=1780415303, model='claude-sonnet-4-5-20250929', object='chat.completion', system_fingerprint=None, choices=[Choices(finish_reason='stop', index=0, message=Message(content="Hello! I'm doing well, thank you for asking. How are you doing today? Is there something I can help you with?", role='assistant', tool_calls=None, function_call=None, provider_specific_fields={'citations': None, 'thinking_blocks': None}))], usage=Usage(completion_tokens=30, prompt_tokens=13, total_tokens=43, completion_tokens_details=CompletionTokensDetailsWrapper(accepted_prediction_tokens=None, audio_tokens=None, reasoning_tokens=0, rejected_prediction_tokens=None, text_tokens=30, image_tokens=None, video_tokens=None), prompt_tokens_details=PromptTokensDetailsWrapper(audio_tokens=None, cached_tokens=0, text_tokens=13, image_tokens=None, video_tokens=None, cache_creation_tokens=0, cache_creation_token_details=CacheCreationTokenDetails(ephemeral_5m_input_tokens=0, ephemeral_1h_input_tokens=0)), cache_creation_input_tokens=0, cache_read_input_tokens=0, inference_geo='not_available', speed=None))
# DEBUG:LiteLLM:selected model name for cost calculation: anthropic/claude-sonnet-4-5-20250929
# 15:48:23 - LiteLLM:DEBUG: litellm_logging.py:1568 - response_cost: 0.000489
# DEBUG:LiteLLM:response_cost: 0.000489

# %% [markdown]
# ### *Moonshot AI*

# %%
from litellm import completion
from google.colab import userdata

response = completion(
    api_key=userdata.get('MOONSHOT_API_KEY'),
    api_base="https://api.moonshot.ai/v1",
    model = "moonshot/moonshot-v1-8k",
    messages = [{ "content": "Hello, how are you?","role": "user"}]
)
print("Moonshot Response\n")
print(response)
# Out:
# 15:49:16 - LiteLLM:DEBUG: utils.py:485 -
#
# DEBUG:LiteLLM:
#
# 15:49:16 - LiteLLM:DEBUG: utils.py:485 - Request to litellm:
# DEBUG:LiteLLM:Request to litellm:
# 15:49:16 - LiteLLM:DEBUG: utils.py:485 - litellm.completion(REDACTED', api_base='https://api.moonshot.ai/v1', model='moonshot/moonshot-v1-8k', messages=[{'content': 'Hello, how are you?', 'role': 'user'}])
# DEBUG:LiteLLM:litellm.completion(REDACTED', api_base='https://api.moonshot.ai/v1', model='moonshot/moonshot-v1-8k', messages=[{'content': 'Hello, how are you?', 'role': 'user'}])
# 15:49:16 - LiteLLM:DEBUG: utils.py:485 -
#
# DEBUG:LiteLLM:
#
# 15:49:16 - LiteLLM:DEBUG: utils.py:1011 - Removing thought signatures from tool call IDs for non-Gemini model
# DEBUG:LiteLLM:Removing thought signatures from tool call IDs for non-Gemini model
# 15:49:16 - LiteLLM:DEBUG: litellm_logging.py:563 - self.optional_params: {}
# DEBUG:LiteLLM:self.optional_params: {}
# 15:49:16 - LiteLLM:DEBUG: utils.py:485 - SYNC kwargs[caching]: False; litellm.cache: None; kwargs.get('cache')['no-cache']: False
# DEBUG:LiteLLM:SYNC kwargs[caching]: False; litellm.cache: None; kwargs.get('cache')['no-cache']: False
# 15:49:16 - LiteLLM:DEBUG: utils.py:5745 - checking potential_model_names in litellm.model_cost: {'split_model': 'moonshot-v1-8k', 'combined_model_name': 'moonshot/moonshot-v1-8k', 'stripped_model_name': 'moonshot-v1-8k', 'combined_stripped_model_name': 'moonshot/moonshot-v1-8k', 'custom_llm_provider': 'moonshot'}
# DEBUG:LiteLLM:checking potential_model_names in litellm.model_cost: {'split_model': 'moonshot-v1-8k', 'combined_model_name': 'moonshot/moonshot-v1-8k', 'stripped_model_name': 'moonshot-v1-8k', 'combined_stripped_model_name': 'moonshot/moonshot-v1-8k', 'custom_llm_provider': 'moonshot'}
# 15:49:16 - LiteLLM:INFO: utils.py:4083 -
# LiteLLM completion() model= moonshot-v1-8k; provider = moonshot
# INFO:LiteLLM:
# LiteLLM completion() model= moonshot-v1-8k; provider = moonshot
# 15:49:16 - LiteLLM:DEBUG: utils.py:4086 -
# LiteLLM: Params passed to completion() {'model': 'moonshot-v1-8k', 'functions': None, 'function_call': None, 'temperature': None, 'top_p': None, 'n': None, 'stream': None, 'stream_options': None, 'stop': None, 'max_tokens': None, 'max_completion_tokens': None, 'modalities': None, 'prediction': None, 'audio': None, 'presence_penalty': None, 'frequency_penalty': None, 'logit_bias': None, 'user': None, 'custom_llm_provider': 'moonshot', 'response_format': None, 'seed': None, 'tools': None, 'tool_choice': None, 'max_retries': None, 'logprobs': None, 'top_logprobs': None, 'extra_headers': None, 'api_version': None, 'parallel_tool_calls': None, 'drop_params': None, 'allowed_openai_params': None, 'reasoning_effort': None, 'verbosity': None, 'additional_drop_params': None, 'messages': [{'content': 'Hello, how are you?', 'role': 'user'}], 'thinking': None, 'web_search_options': None, 'safety_identifier': None, 'service_tier': None}
# DEBUG:LiteLLM:
# LiteLLM: Params passed to completion() {'model': 'moonshot-v1-8k', 'functions': None, 'function_call': None, 'temperature': None, 'top_p': None, 'n': None, 'stream': None, 'stream_options': None, 'stop': None, 'max_tokens': None, 'max_completion_tokens': None, 'modalities': None, 'prediction': None, 'audio': None, 'presence_penalty': None, 'frequency_penalty': None, 'logit_bias': None, 'user': None, 'custom_llm_provider': 'moonshot', 'response_format': None, 'seed': None, 'tools': None, 'tool_choice': None, 'max_retries': None, 'logprobs': None, 'top_logprobs': None, 'extra_headers': None, 'api_version': None, 'parallel_tool_calls': None, 'drop_params': None, 'allowed_openai_params': None, 'reasoning_effort': None, 'verbosity': None, 'additional_drop_params': None, 'messages': [{'content': 'Hello, how are you?', 'role': 'user'}], 'thinking': None, 'web_search_options': None, 'safety_identifier': None, 'service_tier': None}
# 15:49:16 - LiteLLM:DEBUG: utils.py:4089 -
# LiteLLM: Non-Default params passed to completion() {}
# DEBUG:LiteLLM:
# LiteLLM: Non-Default params passed to completion() {}
# 15:49:16 - LiteLLM:DEBUG: utils.py:485 - Final returned optional params: {'extra_body': {}}
# DEBUG:LiteLLM:Final returned optional params: {'extra_body': {}}
# 15:49:16 - LiteLLM:DEBUG: litellm_logging.py:563 - self.optional_params: {'extra_body': {}}
# DEBUG:LiteLLM:self.optional_params: {'extra_body': {}}
# 15:49:16 - LiteLLM:DEBUG: utils.py:5745 - checking potential_model_names in litellm.model_cost: {'split_model': 'moonshot-v1-8k', 'combined_model_name': 'moonshot/moonshot-v1-8k', 'stripped_model_name': 'moonshot-v1-8k', 'combined_stripped_model_name': 'moonshot/moonshot-v1-8k', 'custom_llm_provider': 'moonshot'}
# DEBUG:LiteLLM:checking potential_model_names in litellm.model_cost: {'split_model': 'moonshot-v1-8k', 'combined_model_name': 'moonshot/moonshot-v1-8k', 'stripped_model_name': 'moonshot-v1-8k', 'combined_stripped_model_name': 'moonshot/moonshot-v1-8k', 'custom_llm_provider': 'moonshot'}
# 15:49:16 - LiteLLM:DEBUG: utils.py:5745 - checking potential_model_names in litellm.model_cost: {'split_model': 'moonshot-v1-8k', 'combined_model_name': 'moonshot/moonshot-v1-8k', 'stripped_model_name': 'moonshot-v1-8k', 'combined_stripped_model_name': 'moonshot/moonshot-v1-8k', 'custom_llm_provider': 'moonshot'}
# DEBUG:LiteLLM:checking potential_model_names in litellm.model_cost: {'split_model': 'moonshot-v1-8k', 'combined_model_name': 'moonshot/moonshot-v1-8k', 'stripped_model_name': 'moonshot-v1-8k', 'combined_stripped_model_name': 'moonshot/moonshot-v1-8k', 'custom_llm_provider': 'moonshot'}
# 15:49:16 - LiteLLM:DEBUG: litellm_logging.py:1170 -
#
# POST Request Sent from LiteLLM:
# curl -X POST \
# https://api.moonshot.ai/v1/ \
# -d '{'model': 'moonshot-v1-8k', 'messages': [{'content': 'Hello, how are you?', 'role': 'user'}], 'extra_body': {}}'
#
#
# DEBUG:LiteLLM:
#
# POST Request Sent from LiteLLM:
# curl -X POST \
# https://api.moonshot.ai/v1/ \
# -d '{'model': 'moonshot-v1-8k', 'messages': [{'content': 'Hello, how are you?', 'role': 'user'}], 'extra_body': {}}'
#
#
# 15:49:18 - LiteLLM:DEBUG: main.py:7434 - openai.py: Received openai error - Error code: 429 - {'error': {'message': 'Your account org-cb1fb6ce79b54be8a473a53ac2170e88 <ak-fahgoyb3xufi11cfuomi> is suspended due to insufficient balance, please recharge your account or check your plan and billing details', 'type': 'exceeded_current_quota_error'}}
# DEBUG:LiteLLM:openai.py: Received openai error - Error code: 429 - {'error': {'message': 'Your account org-cb1fb6ce79b54be8a473a53ac2170e88 <ak-fahgoyb3xufi11cfuomi> is suspended due to insufficient balance, please recharge your account or check your plan and billing details', 'type': 'exceeded_current_quota_error'}}
# 15:49:18 - LiteLLM:DEBUG: litellm_logging.py:1243 - RAW RESPONSE:
# Error code: 429 - {'error': {'message': 'Your account org-cb1fb6ce79b54be8a473a53ac2170e88 <ak-fahgoyb3xufi11cfuomi> is suspended due to insufficient balance, please recharge your account or check your plan and billing details', 'type': 'exceeded_current_quota_error'}}
#
#
# DEBUG:LiteLLM:RAW RESPONSE:
# Error code: 429 - {'error': {'message': 'Your account org-cb1fb6ce79b54be8a473a53ac2170e88 <ak-fahgoyb3xufi11cfuomi> is suspended due to insufficient balance, please recharge your account or check your plan and billing details', 'type': 'exceeded_current_quota_error'}}
#
#
# 15:49:18 - LiteLLM:DEBUG: exception_mapping_utils.py:2498 - Logging Details: logger_fn - None | callable(logger_fn) - False
# DEBUG:LiteLLM:Logging Details: logger_fn - None | callable(logger_fn) - False
# 15:49:18 - LiteLLM:DEBUG: litellm_logging.py:2938 - Logging Details LiteLLM-Failure Call: []
# DEBUG:LiteLLM:Logging Details LiteLLM-Failure Call: []
# Give Feedback / Get Help: https://github.com/BerriAI/litellm/issues/new
# LiteLLM.Info: If you need to debug this error, use `litellm._turn_on_debug()'.
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/litellm/llms/openai/openai.py in completion(self, model_response, timeout, optional_params, litellm_params, logging_obj, model, messages, print_verbose, api_key, api_base, api_version, dynamic_params, azure_ad_token, acompletion, logger_fn, headers, custom_prompt_dict, client, organization, custom_llm_provider, drop_params, shared_session)
#     851                     else:
# --> 852                         raise e
#     853         except OpenAIError as e:
#
# /usr/local/lib/python3.12/dist-packages/litellm/llms/openai/openai.py in completion(self, model_response, timeout, optional_params, litellm_params, logging_obj, model, messages, print_verbose, api_key, api_base, api_version, dynamic_params, azure_ad_token, acompletion, logger_fn, headers, custom_prompt_dict, client, organization, custom_llm_provider, drop_params, shared_session)
#     779                             response,
# --> 780                         ) = self.make_sync_openai_chat_completion_request(
#     781                             openai_client=openai_client,
#
# /usr/local/lib/python3.12/dist-packages/litellm/litellm_core_utils/logging_utils.py in sync_wrapper(*args, **kwargs)
#     343             try:
# --> 344                 result = func(*args, **kwargs)
#     345                 return result
#
# /usr/local/lib/python3.12/dist-packages/litellm/llms/openai/openai.py in make_sync_openai_chat_completion_request(self, openai_client, data, timeout, logging_obj)
#     502             else:
# --> 503                 raise e
#     504
#
# /usr/local/lib/python3.12/dist-packages/litellm/llms/openai/openai.py in make_sync_openai_chat_completion_request(self, openai_client, data, timeout, logging_obj)
#     477         try:
# --> 478             raw_response = openai_client.chat.completions.with_raw_response.create(
#     479                 **data, timeout=timeout
#
# /usr/local/lib/python3.12/dist-packages/openai/_legacy_response.py in wrapped(*args, **kwargs)
#     366
# --> 367         return cast(LegacyAPIResponse[R], func(*args, **kwargs))
#     368
#
# /usr/local/lib/python3.12/dist-packages/openai/_utils/_utils.py in wrapper(*args, **kwargs)
#     297                 raise TypeError(msg)
# --> 298             return func(*args, **kwargs)
#     299
#
# /usr/local/lib/python3.12/dist-packages/openai/resources/chat/completions/completions.py in create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, prompt_cache_key, prompt_cache_retention, reasoning_effort, response_format, safety_identifier, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, verbosity, web_search_options, extra_headers, extra_query, extra_body, timeout)
#    1214         validate_response_format(response_format)
# -> 1215         return self._post(
#    1216             "/chat/completions",
#
# /usr/local/lib/python3.12/dist-packages/openai/_base_client.py in post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1331         )
# -> 1332         return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#    1333
#
# /usr/local/lib/python3.12/dist-packages/openai/_base_client.py in request(self, cast_to, options, stream, stream_cls)
#    1104                 log.debug("Re-raising status error")
# -> 1105                 raise self._make_status_error_from_response(err.response) from None
#    1106
#
# RateLimitError: Error code: 429 - {'error': {'message': 'Your account org-cb1fb6ce79b54be8a473a53ac2170e88 <ak-fahgoyb3xufi11cfuomi> is suspended due to insufficient balance, please recharge your account or check your plan and billing details', 'type': 'exceeded_current_quota_error'}}
#
# During handling of the above exception, another exception occurred:
#
# OpenAIError                               Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/litellm/main.py in completion(model, messages, timeout, temperature, top_p, n, stream, stream_options, stop, max_completion_tokens, max_tokens, modalities, prediction, audio, presence_penalty, frequency_penalty, logit_bias, user, reasoning_effort, verbosity, response_format, seed, tools, tool_choice, logprobs, top_logprobs, parallel_tool_calls, web_search_options, deployment_id, extra_headers, safety_identifier, service_tier, functions, function_call, base_url, api_version, api_key, model_list, thinking, shared_session, enable_json_schema_validation, **kwargs)
#    2773                 )
# -> 2774                 raise e
#    2775
#
# /usr/local/lib/python3.12/dist-packages/litellm/main.py in completion(model, messages, timeout, temperature, top_p, n, stream, stream_options, stop, max_completion_tokens, max_tokens, modalities, prediction, audio, presence_penalty, frequency_penalty, logit_bias, user, reasoning_effort, verbosity, response_format, seed, tools, tool_choice, logprobs, top_logprobs, parallel_tool_calls, web_search_options, deployment_id, extra_headers, safety_identifier, service_tier, functions, function_call, base_url, api_version, api_key, model_list, thinking, shared_session, enable_json_schema_validation, **kwargs)
#    2745                 else:
# -> 2746                     response = openai_chat_completions.completion(
#    2747                         model=model,
#
# /usr/local/lib/python3.12/dist-packages/litellm/llms/openai/openai.py in completion(self, model_response, timeout, optional_params, litellm_params, logging_obj, model, messages, print_verbose, api_key, api_base, api_version, dynamic_params, azure_ad_token, acompletion, logger_fn, headers, custom_prompt_dict, client, organization, custom_llm_provider, drop_params, shared_session)
#     862                 error_headers = getattr(error_response, "headers", None)
# --> 863             raise OpenAIError(
#     864                 status_code=status_code,
#
# OpenAIError: Error code: 429 - {'error': {'message': 'Your account org-cb1fb6ce79b54be8a473a53ac2170e88 <ak-fahgoyb3xufi11cfuomi> is suspended due to insufficient balance, please recharge your account or check your plan and billing details', 'type': 'exceeded_current_quota_error'}}
#
# During handling of the above exception, another exception occurred:
#
# RateLimitError                            Traceback (most recent call last)
# /tmp/ipykernel_6587/1850392976.py in <cell line: 0>()
#       5 os.environ["MOONSHOT_API_KEY"] = userdata.get('MOONSHOT_API_KEY')
#       6
# ----> 7 response = completion(
#       8     api_key=userdata.get('MOONSHOT_API_KEY'),
#       9     api_base="https://api.moonshot.ai/v1",
#
# /usr/local/lib/python3.12/dist-packages/litellm/utils.py in wrapper(*args, **kwargs)
#    1773                     e, traceback_exception, start_time, end_time
#    1774                 )  # DO NOT MAKE THREADED - router retry fallback relies on this!
# -> 1775             raise e
#    1776
#    1777     @wraps(original_function)
#
# /usr/local/lib/python3.12/dist-packages/litellm/utils.py in wrapper(*args, **kwargs)
#    1594                     print_verbose(f"Error while checking max token limit: {str(e)}")
#    1595             # MODEL CALL
# -> 1596             result = original_function(*args, **kwargs)
#    1597             end_time = datetime.datetime.now()
#    1598             if _is_streaming_request(
#
# /usr/local/lib/python3.12/dist-packages/litellm/main.py in completion(model, messages, timeout, temperature, top_p, n, stream, stream_options, stop, max_completion_tokens, max_tokens, modalities, prediction, audio, presence_penalty, frequency_penalty, logit_bias, user, reasoning_effort, verbosity, response_format, seed, tools, tool_choice, logprobs, top_logprobs, parallel_tool_calls, web_search_options, deployment_id, extra_headers, safety_identifier, service_tier, functions, function_call, base_url, api_version, api_key, model_list, thinking, shared_session, enable_json_schema_validation, **kwargs)
#    4511     except Exception as e:
#    4512         ## Map to OpenAI Exception
# -> 4513         raise exception_type(
#    4514             model=model,
#    4515             custom_llm_provider=custom_llm_provider,
#
# /usr/local/lib/python3.12/dist-packages/litellm/litellm_core_utils/exception_mapping_utils.py in exception_type(model, original_exception, custom_llm_provider, completion_kwargs, extra_kwargs)
#    2464         if exception_mapping_worked:
#    2465             setattr(e, "litellm_response_headers", litellm_response_headers)
# -> 2466             raise e
#    2467         else:
#    2468             for error_type in litellm.LITELLM_EXCEPTION_TYPES:
#
# /usr/local/lib/python3.12/dist-packages/litellm/litellm_core_utils/exception_mapping_utils.py in exception_type(model, original_exception, custom_llm_provider, completion_kwargs, extra_kwargs)
#     399                 if ExceptionCheckers.is_error_str_rate_limit(error_str):
#     400                     exception_mapping_worked = True
# --> 401                     raise RateLimitError(
#     402                         message=f"RateLimitError: {exception_provider} - {message}",
#     403                         model=model,
#
# RateLimitError: litellm.RateLimitError: RateLimitError: MoonshotException - Your account org-cb1fb6ce79b54be8a473a53ac2170e88 <ak-fahgoyb3xufi11cfuomi> is suspended due to insufficient balance, please recharge your account or check your plan and billing details

# %% [markdown]
# ### *OpenRouter*

# %%
from litellm import completion
from google.colab import userdata

response = completion(
    api_key=userdata.get('OPENROUTER_API_KEY'),
    api_base="https://openrouter.ai/api/v1",
    model = "openrouter/minimax/minimax-m3",
    messages = [{ "content": "Hello, how are you?","role": "user"}]
)
print("Openrouter Response\n")
print(response)
# Out:
# 15:51:17 - LiteLLM:DEBUG: utils.py:485 -
#
# DEBUG:LiteLLM:
#
# 15:51:17 - LiteLLM:DEBUG: utils.py:485 - Request to litellm:
# DEBUG:LiteLLM:Request to litellm:
# 15:51:17 - LiteLLM:DEBUG: utils.py:485 - litellm.completion(REDACTED', api_base='https://openrouter.ai/api/v1', model='openrouter/minimax/minimax-m3', messages=[{'content': 'Hello, how are you?', 'role': 'user'}])
# DEBUG:LiteLLM:litellm.completion(REDACTED', api_base='https://openrouter.ai/api/v1', model='openrouter/minimax/minimax-m3', messages=[{'content': 'Hello, how are you?', 'role': 'user'}])
# 15:51:17 - LiteLLM:DEBUG: utils.py:485 -
#
# DEBUG:LiteLLM:
#
# 15:51:17 - LiteLLM:DEBUG: utils.py:1011 - Removing thought signatures from tool call IDs for non-Gemini model
# DEBUG:LiteLLM:Removing thought signatures from tool call IDs for non-Gemini model
# 15:51:17 - LiteLLM:DEBUG: litellm_logging.py:563 - self.optional_params: {}
# DEBUG:LiteLLM:self.optional_params: {}
# 15:51:17 - LiteLLM:DEBUG: utils.py:485 - SYNC kwargs[caching]: False; litellm.cache: None; kwargs.get('cache')['no-cache']: False
# DEBUG:LiteLLM:SYNC kwargs[caching]: False; litellm.cache: None; kwargs.get('cache')['no-cache']: False
# 15:51:17 - LiteLLM:DEBUG: utils.py:5745 - checking potential_model_names in litellm.model_cost: {'split_model': 'minimax/minimax-m3', 'combined_model_name': 'openrouter/minimax/minimax-m3', 'stripped_model_name': 'minimax/minimax-m3', 'combined_stripped_model_name': 'openrouter/minimax/minimax-m3', 'custom_llm_provider': 'openrouter'}
# DEBUG:LiteLLM:checking potential_model_names in litellm.model_cost: {'split_model': 'minimax/minimax-m3', 'combined_model_name': 'openrouter/minimax/minimax-m3', 'stripped_model_name': 'minimax/minimax-m3', 'combined_stripped_model_name': 'openrouter/minimax/minimax-m3', 'custom_llm_provider': 'openrouter'}
# 15:51:17 - LiteLLM:DEBUG: utils.py:6050 - Error getting model info: This model isn't mapped yet. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json
# DEBUG:LiteLLM:Error getting model info: This model isn't mapped yet. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json
# 15:51:17 - LiteLLM:DEBUG: main.py:985 - Error getting model info: This model isn't mapped yet. model=minimax/minimax-m3, custom_llm_provider=openrouter. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json.
# DEBUG:LiteLLM:Error getting model info: This model isn't mapped yet. model=minimax/minimax-m3, custom_llm_provider=openrouter. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json.
# 15:51:17 - LiteLLM:DEBUG: utils.py:5745 - checking potential_model_names in litellm.model_cost: {'split_model': 'minimax/minimax-m3', 'combined_model_name': 'openrouter/minimax/minimax-m3', 'stripped_model_name': 'minimax/minimax-m3', 'combined_stripped_model_name': 'openrouter/minimax/minimax-m3', 'custom_llm_provider': 'openrouter'}
# DEBUG:LiteLLM:checking potential_model_names in litellm.model_cost: {'split_model': 'minimax/minimax-m3', 'combined_model_name': 'openrouter/minimax/minimax-m3', 'stripped_model_name': 'minimax/minimax-m3', 'combined_stripped_model_name': 'openrouter/minimax/minimax-m3', 'custom_llm_provider': 'openrouter'}
# 15:51:17 - LiteLLM:DEBUG: utils.py:6050 - Error getting model info: This model isn't mapped yet. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json
# DEBUG:LiteLLM:Error getting model info: This model isn't mapped yet. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json
# 15:51:17 - LiteLLM:DEBUG: utils.py:2634 - Model not found or error in checking supports_reasoning support. You passed model=minimax/minimax-m3, custom_llm_provider=openrouter. Error: This model isn't mapped yet. model=minimax/minimax-m3, custom_llm_provider=openrouter. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json.
# DEBUG:LiteLLM:Model not found or error in checking supports_reasoning support. You passed model=minimax/minimax-m3, custom_llm_provider=openrouter. Error: This model isn't mapped yet. model=minimax/minimax-m3, custom_llm_provider=openrouter. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json.
# 15:51:17 - LiteLLM:DEBUG: utils.py:5745 - checking potential_model_names in litellm.model_cost: {'split_model': 'minimax-m3', 'combined_model_name': 'minimax/minimax-m3', 'stripped_model_name': 'minimax-m3', 'combined_stripped_model_name': 'minimax/minimax-m3', 'custom_llm_provider': 'minimax'}
# DEBUG:LiteLLM:checking potential_model_names in litellm.model_cost: {'split_model': 'minimax-m3', 'combined_model_name': 'minimax/minimax-m3', 'stripped_model_name': 'minimax-m3', 'combined_stripped_model_name': 'minimax/minimax-m3', 'custom_llm_provider': 'minimax'}
# 15:51:17 - LiteLLM:DEBUG: utils.py:6050 - Error getting model info: This model isn't mapped yet. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json
# DEBUG:LiteLLM:Error getting model info: This model isn't mapped yet. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json
# 15:51:17 - LiteLLM:DEBUG: utils.py:2634 - Model not found or error in checking supports_reasoning support. You passed model=minimax-m3, custom_llm_provider=minimax. Error: This model isn't mapped yet. model=minimax-m3, custom_llm_provider=minimax. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json.
# DEBUG:LiteLLM:Model not found or error in checking supports_reasoning support. You passed model=minimax-m3, custom_llm_provider=minimax. Error: This model isn't mapped yet. model=minimax-m3, custom_llm_provider=minimax. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json.
# 15:51:17 - LiteLLM:INFO: utils.py:4083 -
# LiteLLM completion() model= minimax/minimax-m3; provider = openrouter
# INFO:LiteLLM:
# LiteLLM completion() model= minimax/minimax-m3; provider = openrouter
# 15:51:17 - LiteLLM:DEBUG: utils.py:4086 -
# LiteLLM: Params passed to completion() {'model': 'minimax/minimax-m3', 'functions': None, 'function_call': None, 'temperature': None, 'top_p': None, 'n': None, 'stream': None, 'stream_options': None, 'stop': None, 'max_tokens': None, 'max_completion_tokens': None, 'modalities': None, 'prediction': None, 'audio': None, 'presence_penalty': None, 'frequency_penalty': None, 'logit_bias': None, 'user': None, 'custom_llm_provider': 'openrouter', 'response_format': None, 'seed': None, 'tools': None, 'tool_choice': None, 'max_retries': None, 'logprobs': None, 'top_logprobs': None, 'extra_headers': None, 'api_version': None, 'parallel_tool_calls': None, 'drop_params': None, 'allowed_openai_params': None, 'reasoning_effort': None, 'verbosity': None, 'additional_drop_params': None, 'messages': [{'content': 'Hello, how are you?', 'role': 'user'}], 'thinking': None, 'web_search_options': None, 'safety_identifier': None, 'service_tier': None}
# DEBUG:LiteLLM:
# LiteLLM: Params passed to completion() {'model': 'minimax/minimax-m3', 'functions': None, 'function_call': None, 'temperature': None, 'top_p': None, 'n': None, 'stream': None, 'stream_options': None, 'stop': None, 'max_tokens': None, 'max_completion_tokens': None, 'modalities': None, 'prediction': None, 'audio': None, 'presence_penalty': None, 'frequency_penalty': None, 'logit_bias': None, 'user': None, 'custom_llm_provider': 'openrouter', 'response_format': None, 'seed': None, 'tools': None, 'tool_choice': None, 'max_retries': None, 'logprobs': None, 'top_logprobs': None, 'extra_headers': None, 'api_version': None, 'parallel_tool_calls': None, 'drop_params': None, 'allowed_openai_params': None, 'reasoning_effort': None, 'verbosity': None, 'additional_drop_params': None, 'messages': [{'content': 'Hello, how are you?', 'role': 'user'}], 'thinking': None, 'web_search_options': None, 'safety_identifier': None, 'service_tier': None}
# 15:51:17 - LiteLLM:DEBUG: utils.py:4089 -
# LiteLLM: Non-Default params passed to completion() {}
# DEBUG:LiteLLM:
# LiteLLM: Non-Default params passed to completion() {}
# 15:51:17 - LiteLLM:DEBUG: utils.py:5745 - checking potential_model_names in litellm.model_cost: {'split_model': 'minimax/minimax-m3', 'combined_model_name': 'openrouter/minimax/minimax-m3', 'stripped_model_name': 'minimax/minimax-m3', 'combined_stripped_model_name': 'openrouter/minimax/minimax-m3', 'custom_llm_provider': 'openrouter'}
# DEBUG:LiteLLM:checking potential_model_names in litellm.model_cost: {'split_model': 'minimax/minimax-m3', 'combined_model_name': 'openrouter/minimax/minimax-m3', 'stripped_model_name': 'minimax/minimax-m3', 'combined_stripped_model_name': 'openrouter/minimax/minimax-m3', 'custom_llm_provider': 'openrouter'}
# 15:51:17 - LiteLLM:DEBUG: utils.py:6050 - Error getting model info: This model isn't mapped yet. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json
# DEBUG:LiteLLM:Error getting model info: This model isn't mapped yet. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json
# 15:51:17 - LiteLLM:DEBUG: utils.py:2634 - Model not found or error in checking supports_reasoning support. You passed model=minimax/minimax-m3, custom_llm_provider=openrouter. Error: This model isn't mapped yet. model=minimax/minimax-m3, custom_llm_provider=openrouter. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json.
# DEBUG:LiteLLM:Model not found or error in checking supports_reasoning support. You passed model=minimax/minimax-m3, custom_llm_provider=openrouter. Error: This model isn't mapped yet. model=minimax/minimax-m3, custom_llm_provider=openrouter. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json.
# 15:51:17 - LiteLLM:DEBUG: utils.py:5745 - checking potential_model_names in litellm.model_cost: {'split_model': 'minimax-m3', 'combined_model_name': 'minimax/minimax-m3', 'stripped_model_name': 'minimax-m3', 'combined_stripped_model_name': 'minimax/minimax-m3', 'custom_llm_provider': 'minimax'}
# DEBUG:LiteLLM:checking potential_model_names in litellm.model_cost: {'split_model': 'minimax-m3', 'combined_model_name': 'minimax/minimax-m3', 'stripped_model_name': 'minimax-m3', 'combined_stripped_model_name': 'minimax/minimax-m3', 'custom_llm_provider': 'minimax'}
# 15:51:17 - LiteLLM:DEBUG: utils.py:6050 - Error getting model info: This model isn't mapped yet. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json
# DEBUG:LiteLLM:Error getting model info: This model isn't mapped yet. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json
# 15:51:17 - LiteLLM:DEBUG: utils.py:2634 - Model not found or error in checking supports_reasoning support. You passed model=minimax-m3, custom_llm_provider=minimax. Error: This model isn't mapped yet. model=minimax-m3, custom_llm_provider=minimax. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json.
# DEBUG:LiteLLM:Model not found or error in checking supports_reasoning support. You passed model=minimax-m3, custom_llm_provider=minimax. Error: This model isn't mapped yet. model=minimax-m3, custom_llm_provider=minimax. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json.
# 15:51:17 - LiteLLM:DEBUG: utils.py:485 - Final returned optional params: {'extra_body': {}}
# DEBUG:LiteLLM:Final returned optional params: {'extra_body': {}}
# 15:51:17 - LiteLLM:DEBUG: litellm_logging.py:563 - self.optional_params: {}
# DEBUG:LiteLLM:self.optional_params: {}
# 15:51:17 - LiteLLM:DEBUG: utils.py:5745 - checking potential_model_names in litellm.model_cost: {'split_model': 'minimax/minimax-m3', 'combined_model_name': 'openrouter/minimax/minimax-m3', 'stripped_model_name': 'minimax/minimax-m3', 'combined_stripped_model_name': 'openrouter/minimax/minimax-m3', 'custom_llm_provider': 'openrouter'}
# DEBUG:LiteLLM:checking potential_model_names in litellm.model_cost: {'split_model': 'minimax/minimax-m3', 'combined_model_name': 'openrouter/minimax/minimax-m3', 'stripped_model_name': 'minimax/minimax-m3', 'combined_stripped_model_name': 'openrouter/minimax/minimax-m3', 'custom_llm_provider': 'openrouter'}
# 15:51:17 - LiteLLM:DEBUG: utils.py:6050 - Error getting model info: This model isn't mapped yet. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json
# DEBUG:LiteLLM:Error getting model info: This model isn't mapped yet. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json
# 15:51:17 - LiteLLM:DEBUG: main.py:985 - Error getting model info: This model isn't mapped yet. model=minimax/minimax-m3, custom_llm_provider=openrouter. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json.
# DEBUG:LiteLLM:Error getting model info: This model isn't mapped yet. model=minimax/minimax-m3, custom_llm_provider=openrouter. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json.
# 15:51:17 - LiteLLM:DEBUG: litellm_logging.py:1170 -
#
# POST Request Sent from LiteLLM:
# curl -X POST \
# https://openrouter.ai/api/v1/chat/completions \
# -H 'HTTP-Referer: https://litellm.ai' -H 'X-Title: liteLLM' -H 'Authorization: Be****49' -H 'Content-Type: application/json' \
# -d '{'model': 'minimax/minimax-m3', 'messages': [{'content': 'Hello, how are you?', 'role': 'user'}], 'usage': {'include': True}}'
#
#
# DEBUG:LiteLLM:
#
# POST Request Sent from LiteLLM:
# curl -X POST \
# https://openrouter.ai/api/v1/chat/completions \
# -H 'HTTP-Referer: https://litellm.ai' -H 'X-Title: liteLLM' -H 'Authorization: Be****49' -H 'Content-Type: application/json' \
# -d '{'model': 'minimax/minimax-m3', 'messages': [{'content': 'Hello, how are you?', 'role': 'user'}], 'usage': {'include': True}}'
#
#
# 15:51:19 - LiteLLM:DEBUG: litellm_logging.py:1243 - RAW RESPONSE:
#
#
#
#
#
#
#
#
#
#
# {"id":"gen-1780415477-Rzbfm4it5wZf2y2GiHYx","object":"chat.completion","created":1780415477,"model":"minimax/minimax-m3-20260531","provider":"Minimax","system_fingerprint":null,"service_tier":null,"choices":[{"index":0,"logprobs":null,"finish_reason":"stop","native_finish_reason":"stop","message":{"role":"assistant","content":"Hello! I'm doing well, thank you for asking. How are you doing today? Is there something I can help you with? 😊","refusal":null,"reasoning":"The user is just saying hello and asking how I am. This is a simple greeting, so I'll respond in a friendly and conversational way.","reasoning_details":[{"type":"reasoning.text","text":"The user is just saying hello and asking how I am. This is a simple greeting, so I'll respond in a friendly and conversational way.","format":"unknown","index":0}]}}],"usage":{"prompt_tokens":182,"completion_tokens":57,"total_tokens":239,"cost":0.00009564,"is_byok":false,"prompt_tokens_details":{"cached_tokens":114,"cache_write_tokens":0,"audio_tokens":0,"video_tokens":0},"cost_details":{"upstream_inference_cost":0.00009564,"upstream_inference_prompt_cost":0.00002724,"upstream_inference_completions_cost":0.0000684},"completion_tokens_details":{"reasoning_tokens":33,"image_tokens":0,"audio_tokens":0}}}
#
#
# DEBUG:LiteLLM:RAW RESPONSE:
#
#
#
#
#
#
#
#
#
#
# {"id":"gen-1780415477-Rzbfm4it5wZf2y2GiHYx","object":"chat.completion","created":1780415477,"model":"minimax/minimax-m3-20260531","provider":"Minimax","system_fingerprint":null,"service_tier":null,"choices":[{"index":0,"logprobs":null,"finish_reason":"stop","native_finish_reason":"stop","message":{"role":"assistant","content":"Hello! I'm doing well, thank you for asking. How are you doing today? Is there something I can help you with? 😊","refusal":null,"reasoning":"The user is just saying hello and asking how I am. This is a simple greeting, so I'll respond in a friendly and conversational way.","reasoning_details":[{"type":"reasoning.text","text":"The user is just saying hello and asking how I am. This is a simple greeting, so I'll respond in a friendly and conversational way.","format":"unknown","index":0}]}}],"usage":{"prompt_tokens":182,"completion_tokens":57,"total_tokens":239,"cost":0.00009564,"is_byok":false,"prompt_tokens_details":{"cached_tokens":114,"cache_write_tokens":0,"audio_tokens":0,"video_tokens":0},"cost_details":{"upstream_inference_cost":0.00009564,"upstream_inference_prompt_cost":0.00002724,"upstream_inference_completions_cost":0.0000684},"completion_tokens_details":{"reasoning_tokens":33,"image_tokens":0,"audio_tokens":0}}}
#
#
# 15:51:19 - LiteLLM:DEBUG: litellm_logging.py:1243 - RAW RESPONSE:
# ModelResponse(id='gen-1780415477-Rzbfm4it5wZf2y2GiHYx', created=1780415477, model='minimax/minimax-m3-20260531', object='chat.completion', system_fingerprint=None, choices=[Choices(finish_reason='stop', index=0, message=Message(content="Hello! I'm doing well, thank you for asking. How are you doing today? Is there something I can help you with? 😊", role='assistant', tool_calls=None, function_call=None, reasoning_content="The user is just saying hello and asking how I am. This is a simple greeting, so I'll respond in a friendly and conversational way.", provider_specific_fields={'reasoning_details': [{'type': 'reasoning.text', 'text': "The user is just saying hello and asking how I am. This is a simple greeting, so I'll respond in a friendly and conversational way.", 'format': 'unknown', 'index': 0}], 'refusal': None, 'reasoning': "The user is just saying hello and asking how I am. This is a simple greeting, so I'll respond in a friendly and conversational way.", 'reasoning_content': "The user is just saying hello and asking how I am. This is a simple greeting, so I'll respond in a friendly and conversational way."}), provider_specific_fields={'native_finish_reason': 'stop'})], usage=Usage(completion_tokens=57, prompt_tokens=182, total_tokens=239, completion_tokens_details=CompletionTokensDetailsWrapper(accepted_prediction_tokens=None, audio_tokens=0, reasoning_tokens=33, rejected_prediction_tokens=None, text_tokens=None, image_tokens=0, video_tokens=None), prompt_tokens_details=PromptTokensDetailsWrapper(audio_tokens=0, cached_tokens=114, text_tokens=None, image_tokens=None, video_tokens=0, cache_write_tokens=0), cost=9.564e-05, is_byok=False, cost_details={'upstream_inference_cost': 9.564e-05, 'upstream_inference_prompt_cost': 2.724e-05, 'upstream_inference_completions_cost': 6.84e-05}), provider='Minimax', service_tier=None)
#
#
# DEBUG:LiteLLM:RAW RESPONSE:
# ModelResponse(id='gen-1780415477-Rzbfm4it5wZf2y2GiHYx', created=1780415477, model='minimax/minimax-m3-20260531', object='chat.completion', system_fingerprint=None, choices=[Choices(finish_reason='stop', index=0, message=Message(content="Hello! I'm doing well, thank you for asking. How are you doing today? Is there something I can help you with? 😊", role='assistant', tool_calls=None, function_call=None, reasoning_content="The user is just saying hello and asking how I am. This is a simple greeting, so I'll respond in a friendly and conversational way.", provider_specific_fields={'reasoning_details': [{'type': 'reasoning.text', 'text': "The user is just saying hello and asking how I am. This is a simple greeting, so I'll respond in a friendly and conversational way.", 'format': 'unknown', 'index': 0}], 'refusal': None, 'reasoning': "The user is just saying hello and asking how I am. This is a simple greeting, so I'll respond in a friendly and conversational way.", 'reasoning_content': "The user is just saying hello and asking how I am. This is a simple greeting, so I'll respond in a friendly and conversational way."}), provider_specific_fields={'native_finish_reason': 'stop'})], usage=Usage(completion_tokens=57, prompt_tokens=182, total_tokens=239, completion_tokens_details=CompletionTokensDetailsWrapper(accepted_prediction_tokens=None, audio_tokens=0, reasoning_tokens=33, rejected_prediction_tokens=None, text_tokens=None, image_tokens=0, video_tokens=None), prompt_tokens_details=PromptTokensDetailsWrapper(audio_tokens=0, cached_tokens=114, text_tokens=None, image_tokens=None, video_tokens=0, cache_write_tokens=0), cost=9.564e-05, is_byok=False, cost_details={'upstream_inference_cost': 9.564e-05, 'upstream_inference_prompt_cost': 2.724e-05, 'upstream_inference_completions_cost': 6.84e-05}), provider='Minimax', service_tier=None)
#
#
# 15:51:19 - LiteLLM:INFO: utils.py:1656 - Wrapper: Completed Call, calling success_handler
# INFO:LiteLLM:Wrapper: Completed Call, calling success_handler
# 15:51:19 - LiteLLM:DEBUG: litellm_logging.py:1568 - response_cost: 9.564e-05
# DEBUG:LiteLLM:response_cost: 9.564e-05
# 15:51:19 - LiteLLM:DEBUG: litellm_logging.py:2017 - Logging Details LiteLLM-Success Call: Cache_hit=None
# Openrouter Response
#
# ModelResponse(id='gen-1780415477-Rzbfm4it5wZf2y2GiHYx', created=1780415477, model='minimax/minimax-m3-20260531', object='chat.completion', system_fingerprint=None, choices=[Choices(finish_reason='stop', index=0, message=Message(content="Hello! I'm doing well, thank you for asking. How are you doing today? Is there something I can help you with? 😊", role='assistant', tool_calls=None, function_call=None, reasoning_content="The user is just saying hello and asking how I am. This is a simple greeting, so I'll respond in a friendly and conversational way.", provider_specific_fields={'reasoning_details': [{'type': 'reasoning.text', 'text': "The user is just saying hello and asking how I am. This is a simple greeting, so I'll respond in a friendly and conversational way.", 'format': 'unknown', 'index': 0}], 'refusal': None, 'reasoning': "The user is just saying hello and asking how I am. This is a simple greeting, so I'll respond in a friendly and conversational way.", 'reasoning_content': "The user is just saying hello and asking how I am. This is a simple greeting, so I'll respond in a friendly and conversational way."}), provider_specific_fields={'native_finish_reason': 'stop'})], usage=Usage(completion_tokens=57, prompt_tokens=182, total_tokens=239, completion_tokens_details=CompletionTokensDetailsWrapper(accepted_prediction_tokens=None, audio_tokens=0, reasoning_tokens=33, rejected_prediction_tokens=None, text_tokens=None, image_tokens=0, video_tokens=None), prompt_tokens_details=PromptTokensDetailsWrapper(audio_tokens=0, cached_tokens=114, text_tokens=None, image_tokens=None, video_tokens=0, cache_write_tokens=0), cost=9.564e-05, is_byok=False, cost_details={'upstream_inference_cost': 9.564e-05, 'upstream_inference_prompt_cost': 2.724e-05, 'upstream_inference_completions_cost': 6.84e-05}), provider='Minimax', service_tier=None)
# DEBUG:LiteLLM:Logging Details LiteLLM-Success Call: Cache_hit=None
# 15:51:19 - LiteLLM:DEBUG: utils.py:5745 - checking potential_model_names in litellm.model_cost: {'split_model': 'minimax/minimax-m3-20260531', 'combined_model_name': 'openrouter/minimax/minimax-m3-20260531', 'stripped_model_name': 'minimax/minimax-m3-20260531', 'combined_stripped_model_name': 'openrouter/minimax/minimax-m3-20260531', 'custom_llm_provider': 'openrouter'}
# DEBUG:LiteLLM:checking potential_model_names in litellm.model_cost: {'split_model': 'minimax/minimax-m3-20260531', 'combined_model_name': 'openrouter/minimax/minimax-m3-20260531', 'stripped_model_name': 'minimax/minimax-m3-20260531', 'combined_stripped_model_name': 'openrouter/minimax/minimax-m3-20260531', 'custom_llm_provider': 'openrouter'}
# 15:51:19 - LiteLLM:DEBUG: utils.py:6050 - Error getting model info: This model isn't mapped yet. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json
# DEBUG:LiteLLM:Error getting model info: This model isn't mapped yet. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json

# %% [markdown]
# ### *Foundry Anthropic (azure_ai)*

# %%
from litellm import completion
from google.colab import userdata
import os

response = completion(
    model = "azure_ai/my-claude-sonnet-4-5",
    api_base="https://hb-1959-resource.services.ai.azure.com/anthropic",
    api_key=userdata.get('AZURE_ANTHROPIC_API_KEY'),
    messages = [{"role": "user", "content": "Hello!"}]
)
print("Azure Response\n")
print(response)
# Out:
# 15:34:48 - LiteLLM:DEBUG: utils.py:485 -
#
# DEBUG:LiteLLM:
#
# 15:34:48 - LiteLLM:DEBUG: utils.py:485 - Request to litellm:
# DEBUG:LiteLLM:Request to litellm:
# 15:34:48 - LiteLLM:DEBUG: utils.py:485 - litellm.completion(model='azure_ai/my-claude-sonnet-4-5', api_base='https://hb-1959-resource.services.ai.azure.com/anthropic', REDACTED', messages=[{'role': 'user', 'content': 'Hello!'}])
# DEBUG:LiteLLM:litellm.completion(model='azure_ai/my-claude-sonnet-4-5', api_base='https://hb-1959-resource.services.ai.azure.com/anthropic', REDACTED', messages=[{'role': 'user', 'content': 'Hello!'}])
# 15:34:48 - LiteLLM:DEBUG: utils.py:485 -
#
# DEBUG:LiteLLM:
#
# 15:34:48 - LiteLLM:DEBUG: utils.py:1011 - Removing thought signatures from tool call IDs for non-Gemini model
# DEBUG:LiteLLM:Removing thought signatures from tool call IDs for non-Gemini model
# 15:34:48 - LiteLLM:DEBUG: litellm_logging.py:563 - self.optional_params: {}
# DEBUG:LiteLLM:self.optional_params: {}
# 15:34:48 - LiteLLM:DEBUG: utils.py:485 - SYNC kwargs[caching]: False; litellm.cache: None; kwargs.get('cache')['no-cache']: False
# DEBUG:LiteLLM:SYNC kwargs[caching]: False; litellm.cache: None; kwargs.get('cache')['no-cache']: False
# 15:34:48 - LiteLLM:DEBUG: utils.py:5745 - checking potential_model_names in litellm.model_cost: {'split_model': 'my-claude-sonnet-4-5', 'combined_model_name': 'azure_ai/my-claude-sonnet-4-5', 'stripped_model_name': 'my-claude-sonnet-4-5', 'combined_stripped_model_name': 'azure_ai/my-claude-sonnet-4-5', 'custom_llm_provider': 'azure_ai'}
# DEBUG:LiteLLM:checking potential_model_names in litellm.model_cost: {'split_model': 'my-claude-sonnet-4-5', 'combined_model_name': 'azure_ai/my-claude-sonnet-4-5', 'stripped_model_name': 'my-claude-sonnet-4-5', 'combined_stripped_model_name': 'azure_ai/my-claude-sonnet-4-5', 'custom_llm_provider': 'azure_ai'}
# 15:34:48 - LiteLLM:DEBUG: utils.py:6050 - Error getting model info: This model isn't mapped yet. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json
# DEBUG:LiteLLM:Error getting model info: This model isn't mapped yet. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json
# 15:34:48 - LiteLLM:DEBUG: main.py:985 - Error getting model info: This model isn't mapped yet. model=my-claude-sonnet-4-5, custom_llm_provider=azure_ai. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json.
# DEBUG:LiteLLM:Error getting model info: This model isn't mapped yet. model=my-claude-sonnet-4-5, custom_llm_provider=azure_ai. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json.
# 15:34:48 - LiteLLM:DEBUG: utils.py:5745 - checking potential_model_names in litellm.model_cost: {'split_model': 'my-claude-sonnet-4-5', 'combined_model_name': 'azure_ai/my-claude-sonnet-4-5', 'stripped_model_name': 'my-claude-sonnet-4-5', 'combined_stripped_model_name': 'azure_ai/my-claude-sonnet-4-5', 'custom_llm_provider': 'azure_ai'}
# DEBUG:LiteLLM:checking potential_model_names in litellm.model_cost: {'split_model': 'my-claude-sonnet-4-5', 'combined_model_name': 'azure_ai/my-claude-sonnet-4-5', 'stripped_model_name': 'my-claude-sonnet-4-5', 'combined_stripped_model_name': 'azure_ai/my-claude-sonnet-4-5', 'custom_llm_provider': 'azure_ai'}
# 15:34:48 - LiteLLM:DEBUG: utils.py:6050 - Error getting model info: This model isn't mapped yet. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json
# DEBUG:LiteLLM:Error getting model info: This model isn't mapped yet. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json
# 15:34:48 - LiteLLM:DEBUG: utils.py:2634 - Model not found or error in checking supports_reasoning support. You passed model=my-claude-sonnet-4-5, custom_llm_provider=azure_ai. Error: This model isn't mapped yet. model=my-claude-sonnet-4-5, custom_llm_provider=azure_ai. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json.
# DEBUG:LiteLLM:Model not found or error in checking supports_reasoning support. You passed model=my-claude-sonnet-4-5, custom_llm_provider=azure_ai. Error: This model isn't mapped yet. model=my-claude-sonnet-4-5, custom_llm_provider=azure_ai. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json.
# 15:34:48 - LiteLLM:INFO: utils.py:4083 -
# LiteLLM completion() model= my-claude-sonnet-4-5; provider = azure_ai
# INFO:LiteLLM:
# LiteLLM completion() model= my-claude-sonnet-4-5; provider = azure_ai
# 15:34:48 - LiteLLM:DEBUG: utils.py:4086 -
# LiteLLM: Params passed to completion() {'model': 'my-claude-sonnet-4-5', 'functions': None, 'function_call': None, 'temperature': None, 'top_p': None, 'n': None, 'stream': None, 'stream_options': None, 'stop': None, 'max_tokens': None, 'max_completion_tokens': None, 'modalities': None, 'prediction': None, 'audio': None, 'presence_penalty': None, 'frequency_penalty': None, 'logit_bias': None, 'user': None, 'custom_llm_provider': 'azure_ai', 'response_format': None, 'seed': None, 'tools': None, 'tool_choice': None, 'max_retries': None, 'logprobs': None, 'top_logprobs': None, 'extra_headers': None, 'api_version': None, 'parallel_tool_calls': None, 'drop_params': None, 'allowed_openai_params': None, 'reasoning_effort': None, 'verbosity': None, 'additional_drop_params': None, 'messages': [{'role': 'user', 'content': 'Hello!'}], 'thinking': None, 'web_search_options': None, 'safety_identifier': None, 'service_tier': None}
# DEBUG:LiteLLM:
# LiteLLM: Params passed to completion() {'model': 'my-claude-sonnet-4-5', 'functions': None, 'function_call': None, 'temperature': None, 'top_p': None, 'n': None, 'stream': None, 'stream_options': None, 'stop': None, 'max_tokens': None, 'max_completion_tokens': None, 'modalities': None, 'prediction': None, 'audio': None, 'presence_penalty': None, 'frequency_penalty': None, 'logit_bias': None, 'user': None, 'custom_llm_provider': 'azure_ai', 'response_format': None, 'seed': None, 'tools': None, 'tool_choice': None, 'max_retries': None, 'logprobs': None, 'top_logprobs': None, 'extra_headers': None, 'api_version': None, 'parallel_tool_calls': None, 'drop_params': None, 'allowed_openai_params': None, 'reasoning_effort': None, 'verbosity': None, 'additional_drop_params': None, 'messages': [{'role': 'user', 'content': 'Hello!'}], 'thinking': None, 'web_search_options': None, 'safety_identifier': None, 'service_tier': None}
# 15:34:48 - LiteLLM:DEBUG: utils.py:4089 -
# LiteLLM: Non-Default params passed to completion() {}
# DEBUG:LiteLLM:
# LiteLLM: Non-Default params passed to completion() {}
# 15:34:48 - LiteLLM:DEBUG: utils.py:485 - Final returned optional params: {'extra_body': {}}
# DEBUG:LiteLLM:Final returned optional params: {'extra_body': {}}
# 15:34:48 - LiteLLM:DEBUG: litellm_logging.py:563 - self.optional_params: {'extra_body': {}}
# DEBUG:LiteLLM:self.optional_params: {'extra_body': {}}
# 15:34:48 - LiteLLM:DEBUG: utils.py:5745 - checking potential_model_names in litellm.model_cost: {'split_model': 'my-claude-sonnet-4-5', 'combined_model_name': 'azure_ai/my-claude-sonnet-4-5', 'stripped_model_name': 'my-claude-sonnet-4-5', 'combined_stripped_model_name': 'azure_ai/my-claude-sonnet-4-5', 'custom_llm_provider': 'azure_ai'}
# DEBUG:LiteLLM:checking potential_model_names in litellm.model_cost: {'split_model': 'my-claude-sonnet-4-5', 'combined_model_name': 'azure_ai/my-claude-sonnet-4-5', 'stripped_model_name': 'my-claude-sonnet-4-5', 'combined_stripped_model_name': 'azure_ai/my-claude-sonnet-4-5', 'custom_llm_provider': 'azure_ai'}
# 15:34:48 - LiteLLM:DEBUG: utils.py:6050 - Error getting model info: This model isn't mapped yet. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json
# DEBUG:LiteLLM:Error getting model info: This model isn't mapped yet. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json
# 15:34:48 - LiteLLM:DEBUG: main.py:985 - Error getting model info: This model isn't mapped yet. model=my-claude-sonnet-4-5, custom_llm_provider=azure_ai. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json.
# DEBUG:LiteLLM:Error getting model info: This model isn't mapped yet. model=my-claude-sonnet-4-5, custom_llm_provider=azure_ai. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json.
# 15:34:48 - LiteLLM:DEBUG: litellm_logging.py:1170 -
#
# POST Request Sent from LiteLLM:
# curl -X POST \
# https://hb-1959-resource.services.ai.azure.com/anthropic/v1/messages \
# -H 'anthropic-version: 2023-06-01' -H 'accept: application/json' -H 'content-type: application/json' -H 'REDACTED' -H 'REDACTED' \
# -d '{'model': 'my-claude-sonnet-4-5', 'messages': [{'role': 'user', 'content': [{'type': 'text', 'text': 'Hello!'}]}], 'max_tokens': 4096}'
#
#
# DEBUG:LiteLLM:
#
# POST Request Sent from LiteLLM:
# curl -X POST \
# https://hb-1959-resource.services.ai.azure.com/anthropic/v1/messages \
# -H 'anthropic-version: 2023-06-01' -H 'accept: application/json' -H 'content-type: application/json' -H 'REDACTED' -H 'REDACTED' \
# -d '{'model': 'my-claude-sonnet-4-5', 'messages': [{'role': 'user', 'content': [{'type': 'text', 'text': 'Hello!'}]}], 'max_tokens': 4096}'
#
#
# 15:34:48 - LiteLLM:DEBUG: main.py:7434 - _is_function_call: False
# DEBUG:LiteLLM:_is_function_call: False
# Provider List: https://docs.litellm.ai/docs/providers
# 15:34:49 - LiteLLM:DEBUG: litellm_logging.py:1243 - RAW RESPONSE:
# {"model":"claude-sonnet-4-5-20250929","id":"msg_01U4gbuPgSkYxurasCdb1hbR","type":"message","role":"assistant","content":[{"type":"text","text":"Hello! How can I help you today?"}],"stop_reason":"end_turn","stop_sequence":null,"stop_details":null,"usage":{"input_tokens":9,"cache_creation_input_tokens":0,"cache_read_input_tokens":0,"cache_creation":{"ephemeral_5m_input_tokens":0,"ephemeral_1h_input_tokens":0},"output_tokens":12,"service_tier":"standard","inference_geo":"not_available"}}
#
#
# DEBUG:LiteLLM:RAW RESPONSE:
# {"model":"claude-sonnet-4-5-20250929","id":"msg_01U4gbuPgSkYxurasCdb1hbR","type":"message","role":"assistant","content":[{"type":"text","text":"Hello! How can I help you today?"}],"stop_reason":"end_turn","stop_sequence":null,"stop_details":null,"usage":{"input_tokens":9,"cache_creation_input_tokens":0,"cache_read_input_tokens":0,"cache_creation":{"ephemeral_5m_input_tokens":0,"ephemeral_1h_input_tokens":0},"output_tokens":12,"service_tier":"standard","inference_geo":"not_available"}}
#
#
# 15:34:49 - LiteLLM:INFO: utils.py:1656 - Wrapper: Completed Call, calling success_handler
# INFO:LiteLLM:Wrapper: Completed Call, calling success_handler
# 15:34:50 - LiteLLM:DEBUG: cost_calculator.py:1212 - selected model name for cost calculation: azure_ai/claude-sonnet-4-5-20250929
# DEBUG:LiteLLM:selected model name for cost calculation: azure_ai/claude-sonnet-4-5-20250929
# 15:34:50 - LiteLLM:DEBUG: litellm_logging.py:2017 - Logging Details LiteLLM-Success Call: Cache_hit=None
# DEBUG:LiteLLM:Logging Details LiteLLM-Success Call: Cache_hit=None
# 15:34:50 - LiteLLM:DEBUG: utils.py:5745 - checking potential_model_names in litellm.model_cost: {'split_model': 'claude-sonnet-4-5-20250929', 'combined_model_name': 'azure_ai/claude-sonnet-4-5-20250929', 'stripped_model_name': 'claude-sonnet-4-5-20250929', 'combined_stripped_model_name': 'azure_ai/claude-sonnet-4-5-20250929', 'custom_llm_provider': 'azure_ai'}
# DEBUG:LiteLLM:checking potential_model_names in litellm.model_cost: {'split_model': 'claude-sonnet-4-5-20250929', 'combined_model_name': 'azure_ai/claude-sonnet-4-5-20250929', 'stripped_model_name': 'claude-sonnet-4-5-20250929', 'combined_stripped_model_name': 'azure_ai/claude-sonnet-4-5-20250929', 'custom_llm_provider': 'azure_ai'}
# 15:34:50 - LiteLLM:DEBUG: cost_calculator.py:1212 - selected model name for cost calculation: azure_ai/claude-sonnet-4-5-20250929
# DEBUG:LiteLLM:selected model name for cost calculation: azure_ai/claude-sonnet-4-5-20250929
# 15:34:50 - LiteLLM:DEBUG: utils.py:6050 - Error getting model info: This model isn't mapped yet. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json
# DEBUG:LiteLLM:Error getting model info: This model isn't mapped yet. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json
# 15:34:50 - LiteLLM:DEBUG: utils.py:5745 - checking potential_model_names in litellm.model_cost: {'split_model': 'claude-sonnet-4-5-20250929', 'combined_model_name': 'azure_ai/claude-sonnet-4-5-20250929', 'stripped_model_name': 'claude-sonnet-4-5-20250929', 'combined_stripped_model_name': 'azure_ai/claude-sonnet-4-5-20250929', 'custom_llm_provider': 'azure_ai'}
# DEBUG:LiteLLM:checking potential_model_names in litellm.model_cost: {'split_model': 'claude-sonnet-4-5-20250929', 'combined_model_name': 'azure_ai/claude-sonnet-4-5-20250929', 'stripped_model_name': 'claude-sonnet-4-5-20250929', 'combined_stripped_model_name': 'azure_ai/claude-sonnet-4-5-20250929', 'custom_llm_provider': 'azure_ai'}
# 15:34:50 - LiteLLM:DEBUG: utils.py:2634 - Model not found or error in checking supports_reasoning support. You passed model=claude-sonnet-4-5-20250929, custom_llm_provider=azure_ai. Error: This model isn't mapped yet. model=claude-sonnet-4-5-20250929, custom_llm_provider=azure_ai. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json.
# DEBUG:LiteLLM:Model not found or error in checking supports_reasoning support. You passed model=claude-sonnet-4-5-20250929, custom_llm_provider=azure_ai. Error: This model isn't mapped yet. model=claude-sonnet-4-5-20250929, custom_llm_provider=azure_ai. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json.
# 15:34:50 - LiteLLM:DEBUG: utils.py:6050 - Error getting model info: This model isn't mapped yet. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json
# DEBUG:LiteLLM:Error getting model info: This model isn't mapped yet. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json
# 15:34:50 - LiteLLM:DEBUG: utils.py:5745 - checking potential_model_names in litellm.model_cost: {'split_model': 'claude-sonnet-4-5-20250929', 'combined_model_name': 'azure_ai/claude-sonnet-4-5-20250929', 'stripped_model_name': 'claude-sonnet-4-5-20250929', 'combined_stripped_model_name': 'azure_ai/claude-sonnet-4-5-20250929', 'custom_llm_provider': 'azure_ai'}
# DEBUG:LiteLLM:checking potential_model_names in litellm.model_cost: {'split_model': 'claude-sonnet-4-5-20250929', 'combined_model_name': 'azure_ai/claude-sonnet-4-5-20250929', 'stripped_model_name': 'claude-sonnet-4-5-20250929', 'combined_stripped_model_name': 'azure_ai/claude-sonnet-4-5-20250929', 'custom_llm_provider': 'azure_ai'}
# 15:34:50 - LiteLLM:DEBUG: utils.py:2634 - Model not found or error in checking supports_reasoning support. You passed model=claude-sonnet-4-5-20250929, custom_llm_provider=azure_ai. Error: This model isn't mapped yet. model=claude-sonnet-4-5-20250929, custom_llm_provider=azure_ai. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json.
# DEBUG:LiteLLM:Model not found or error in checking supports_reasoning support. You passed model=claude-sonnet-4-5-20250929, custom_llm_provider=azure_ai. Error: This model isn't mapped yet. model=claude-sonnet-4-5-20250929, custom_llm_provider=azure_ai. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json.
# 15:34:50 - LiteLLM:DEBUG: utils.py:6050 - Error getting model info: This model isn't mapped yet. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json
# DEBUG:LiteLLM:Error getting model info: This model isn't mapped yet. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json
# 15:34:50 - LiteLLM:DEBUG: cost_calculator.py:1730 - litellm.cost_calculator.py::completion_cost() - Error calculating cost for model=azure_ai/claude-sonnet-4-5-20250929 - This model isn't mapped yet. model=claude-sonnet-4-5-20250929, custom_llm_provider=azure_ai. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json.
# DEBUG:LiteLLM:litellm.cost_calculator.py::completion_cost() - Error calculating cost for model=azure_ai/claude-sonnet-4-5-20250929 - This model isn't mapped yet. model=claude-sonnet-4-5-20250929, custom_llm_provider=azure_ai. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json.
# 15:34:50 - LiteLLM:DEBUG: utils.py:5745 - checking potential_model_names in litellm.model_cost: {'split_model': 'claude-sonnet-4-5-20250929', 'combined_model_name': 'azure_ai/claude-sonnet-4-5-20250929', 'stripped_model_name': 'claude-sonnet-4-5-20250929', 'combined_stripped_model_name': 'azure_ai/claude-sonnet-4-5-20250929', 'custom_llm_provider': 'azure_ai'}
# 15:34:50 - LiteLLM:DEBUG: cost_calculator.py:1212 - selected model name for cost calculation: claude-sonnet-4-5-20250929
# DEBUG:LiteLLM:checking potential_model_names in litellm.model_cost: {'split_model': 'claude-sonnet-4-5-20250929', 'combined_model_name': 'azure_ai/claude-sonnet-4-5-20250929', 'stripped_model_name': 'claude-sonnet-4-5-20250929', 'combined_stripped_model_name': 'azure_ai/claude-sonnet-4-5-20250929', 'custom_llm_provider': 'azure_ai'}
# 15:34:50 - LiteLLM:DEBUG: utils.py:6050 - Error getting model info: This model isn't mapped yet. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json
# DEBUG:LiteLLM:selected model name for cost calculation: claude-sonnet-4-5-20250929
# DEBUG:LiteLLM:Error getting model info: This model isn't mapped yet. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json
# 15:34:50 - LiteLLM:DEBUG: utils.py:5745 - checking potential_model_names in litellm.model_cost: {'split_model': 'claude-sonnet-4-5-20250929', 'combined_model_name': 'azure_ai/claude-sonnet-4-5-20250929', 'stripped_model_name': 'claude-sonnet-4-5-20250929', 'combined_stripped_model_name': 'azure_ai/claude-sonnet-4-5-20250929', 'custom_llm_provider': 'azure_ai'}
# DEBUG:LiteLLM:checking potential_model_names in litellm.model_cost: {'split_model': 'claude-sonnet-4-5-20250929', 'combined_model_name': 'azure_ai/claude-sonnet-4-5-20250929', 'stripped_model_name': 'claude-sonnet-4-5-20250929', 'combined_stripped_model_name': 'azure_ai/claude-sonnet-4-5-20250929', 'custom_llm_provider': 'azure_ai'}
# 15:34:50 - LiteLLM:DEBUG: cost_calculator.py:1730 - litellm.cost_calculator.py::completion_cost() - Error calculating cost for model=azure_ai/claude-sonnet-4-5-20250929 - This model isn't mapped yet. model=claude-sonnet-4-5-20250929, custom_llm_provider=azure_ai. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json.
# DEBUG:LiteLLM:litellm.cost_calculator.py::completion_cost() - Error calculating cost for model=azure_ai/claude-sonnet-4-5-20250929 - This model isn't mapped yet. model=claude-sonnet-4-5-20250929, custom_llm_provider=azure_ai. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json.
# 15:34:50 - LiteLLM:DEBUG: utils.py:6050 - Error getting model info: This model isn't mapped yet. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json
# DEBUG:LiteLLM:Error getting model info: This model isn't mapped yet. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json
# 15:34:50 - LiteLLM:DEBUG: cost_calculator.py:1212 - selected model name for cost calculation: claude-sonnet-4-5-20250929
# DEBUG:LiteLLM:selected model name for cost calculation: claude-sonnet-4-5-20250929
# 15:34:50 - LiteLLM:DEBUG: utils.py:2634 - Model not found or error in checking supports_reasoning support. You passed model=claude-sonnet-4-5-20250929, custom_llm_provider=azure_ai. Error: This model isn't mapped yet. model=claude-sonnet-4-5-20250929, custom_llm_provider=azure_ai. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json.
# DEBUG:LiteLLM:Model not found or error in checking supports_reasoning support. You passed model=claude-sonnet-4-5-20250929, custom_llm_provider=azure_ai. Error: This model isn't mapped yet. model=claude-sonnet-4-5-20250929, custom_llm_provider=azure_ai. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json.
# 15:34:50 - LiteLLM:DEBUG: utils.py:5745 - checking potential_model_names in litellm.model_cost: {'split_model': 'claude-sonnet-4-5-20250929', 'combined_model_name': 'azure_ai/claude-sonnet-4-5-20250929', 'stripped_model_name': 'claude-sonnet-4-5-20250929', 'combined_stripped_model_name': 'azure_ai/claude-sonnet-4-5-20250929', 'custom_llm_provider': 'azure_ai'}
# DEBUG:LiteLLM:checking potential_model_names in litellm.model_cost: {'split_model': 'claude-sonnet-4-5-20250929', 'combined_model_name': 'azure_ai/claude-sonnet-4-5-20250929', 'stripped_model_name': 'claude-sonnet-4-5-20250929', 'combined_stripped_model_name': 'azure_ai/claude-sonnet-4-5-20250929', 'custom_llm_provider': 'azure_ai'}
# 15:34:50 - LiteLLM:DEBUG: utils.py:5745 - checking potential_model_names in litellm.model_cost: {'split_model': 'claude-sonnet-4-5-20250929', 'combined_model_name': 'azure_ai/claude-sonnet-4-5-20250929', 'stripped_model_name': 'claude-sonnet-4-5-20250929', 'combined_stripped_model_name': 'azure_ai/claude-sonnet-4-5-20250929', 'custom_llm_provider': 'azure_ai'}
# DEBUG:LiteLLM:checking potential_model_names in litellm.model_cost: {'split_model': 'claude-sonnet-4-5-20250929', 'combined_model_name': 'azure_ai/claude-sonnet-4-5-20250929', 'stripped_model_name': 'claude-sonnet-4-5-20250929', 'combined_stripped_model_name': 'azure_ai/claude-sonnet-4-5-20250929', 'custom_llm_provider': 'azure_ai'}
# 15:34:50 - LiteLLM:DEBUG: utils.py:6050 - Error getting model info: This model isn't mapped yet. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json
# DEBUG:LiteLLM:Error getting model info: This model isn't mapped yet. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json
# 15:34:50 - LiteLLM:DEBUG: utils.py:6050 - Error getting model info: This model isn't mapped yet. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json
# DEBUG:LiteLLM:Error getting model info: This model isn't mapped yet. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json
# 15:34:50 - LiteLLM:DEBUG: utils.py:2634 - Model not found or error in checking supports_reasoning support. You passed model=claude-sonnet-4-5-20250929, custom_llm_provider=azure_ai. Error: This model isn't mapped yet. model=claude-sonnet-4-5-20250929, custom_llm_provider=azure_ai. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json.
# DEBUG:LiteLLM:Model not found or error in checking supports_reasoning support. You passed model=claude-sonnet-4-5-20250929, custom_llm_provider=azure_ai. Error: This model isn't mapped yet. model=claude-sonnet-4-5-20250929, custom_llm_provider=azure_ai. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json.
# 15:34:50 - LiteLLM:DEBUG: cost_calculator.py:1730 - litellm.cost_calculator.py::completion_cost() - Error calculating cost for model=claude-sonnet-4-5-20250929 - This model isn't mapped yet. model=claude-sonnet-4-5-20250929, custom_llm_provider=azure_ai. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json.
# DEBUG:LiteLLM:litellm.cost_calculator.py::completion_cost() - Error calculating cost for model=claude-sonnet-4-5-20250929 - This model isn't mapped yet. model=claude-sonnet-4-5-20250929, custom_llm_provider=azure_ai. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json.
# 15:34:50 - LiteLLM:DEBUG: utils.py:5745 - checking potential_model_names in litellm.model_cost: {'split_model': 'claude-sonnet-4-5-20250929', 'combined_model_name': 'azure_ai/claude-sonnet-4-5-20250929', 'stripped_model_name': 'claude-sonnet-4-5-20250929', 'combined_stripped_model_name': 'azure_ai/claude-sonnet-4-5-20250929', 'custom_llm_provider': 'azure_ai'}
# DEBUG:LiteLLM:checking potential_model_names in litellm.model_cost: {'split_model': 'claude-sonnet-4-5-20250929', 'combined_model_name': 'azure_ai/claude-sonnet-4-5-20250929', 'stripped_model_name': 'claude-sonnet-4-5-20250929', 'combined_stripped_model_name': 'azure_ai/claude-sonnet-4-5-20250929', 'custom_llm_provider': 'azure_ai'}
# 15:34:50 - LiteLLM:DEBUG: cost_calculator.py:1212 - selected model name for cost calculation: azure_ai/my-claude-sonnet-4-5
# DEBUG:LiteLLM:selected model name for cost calculation: azure_ai/my-claude-sonnet-4-5
# 15:34:50 - LiteLLM:DEBUG: utils.py:6050 - Error getting model info: This model isn't mapped yet. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json
# DEBUG:LiteLLM:Error getting model info: This model isn't mapped yet. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json
# 15:34:50 - LiteLLM:DEBUG: cost_calculator.py:1730 - litellm.cost_calculator.py::completion_cost() - Error calculating cost for model=claude-sonnet-4-5-20250929 - This model isn't mapped yet. model=claude-sonnet-4-5-20250929, custom_llm_provider=azure_ai. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json.
# DEBUG:LiteLLM:litellm.cost_calculator.py::completion_cost() - Error calculating cost for model=claude-sonnet-4-5-20250929 - This model isn't mapped yet. model=claude-sonnet-4-5-20250929, custom_llm_provider=azure_ai. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json.
# 15:34:50 - LiteLLM:DEBUG: utils.py:5745 - checking potential_model_names in litellm.model_cost: {'split_model': 'my-claude-sonnet-4-5', 'combined_model_name': 'azure_ai/my-claude-sonnet-4-5', 'stripped_model_name': 'my-claude-sonnet-4-5', 'combined_stripped_model_name': 'azure_ai/my-claude-sonnet-4-5', 'custom_llm_provider': 'azure_ai'}
# DEBUG:LiteLLM:checking potential_model_names in litellm.model_cost: {'split_model': 'my-claude-sonnet-4-5', 'combined_model_name': 'azure_ai/my-claude-sonnet-4-5', 'stripped_model_name': 'my-claude-sonnet-4-5', 'combined_stripped_model_name': 'azure_ai/my-claude-sonnet-4-5', 'custom_llm_provider': 'azure_ai'}
# 15:34:50 - LiteLLM:DEBUG: cost_calculator.py:1212 - selected model name for cost calculation: my-claude-sonnet-4-5
# DEBUG:LiteLLM:selected model name for cost calculation: my-claude-sonnet-4-5
# 15:34:50 - LiteLLM:DEBUG: utils.py:6050 - Error getting model info: This model isn't mapped yet. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json
# DEBUG:LiteLLM:Error getting model info: This model isn't mapped yet. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json
# 15:34:50 - LiteLLM:DEBUG: utils.py:2634 - Model not found or error in checking supports_reasoning support. You passed model=my-claude-sonnet-4-5, custom_llm_provider=azure_ai. Error: This model isn't mapped yet. model=my-claude-sonnet-4-5, custom_llm_provider=azure_ai. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json.
# DEBUG:LiteLLM:Model not found or error in checking supports_reasoning support. You passed model=my-claude-sonnet-4-5, custom_llm_provider=azure_ai. Error: This model isn't mapped yet. model=my-claude-sonnet-4-5, custom_llm_provider=azure_ai. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json.
# 15:34:50 - LiteLLM:DEBUG: utils.py:5745 - checking potential_model_names in litellm.model_cost: {'split_model': 'my-claude-sonnet-4-5', 'combined_model_name': 'azure_ai/my-claude-sonnet-4-5', 'stripped_model_name': 'my-claude-sonnet-4-5', 'combined_stripped_model_name': 'azure_ai/my-claude-sonnet-4-5', 'custom_llm_provider': 'azure_ai'}
# 15:34:50 - LiteLLM:DEBUG: utils.py:5745 - checking potential_model_names in litellm.model_cost: {'split_model': 'my-claude-sonnet-4-5', 'combined_model_name': 'azure_ai/my-claude-sonnet-4-5', 'stripped_model_name': 'my-claude-sonnet-4-5', 'combined_stripped_model_name': 'azure_ai/my-claude-sonnet-4-5', 'custom_llm_provider': 'azure_ai'}
# DEBUG:LiteLLM:checking potential_model_names in litellm.model_cost: {'split_model': 'my-claude-sonnet-4-5', 'combined_model_name': 'azure_ai/my-claude-sonnet-4-5', 'stripped_model_name': 'my-claude-sonnet-4-5', 'combined_stripped_model_name': 'azure_ai/my-claude-sonnet-4-5', 'custom_llm_provider': 'azure_ai'}
# DEBUG:LiteLLM:checking potential_model_names in litellm.model_cost: {'split_model': 'my-claude-sonnet-4-5', 'combined_model_name': 'azure_ai/my-claude-sonnet-4-5', 'stripped_model_name': 'my-claude-sonnet-4-5', 'combined_stripped_model_name': 'azure_ai/my-claude-sonnet-4-5', 'custom_llm_provider': 'azure_ai'}
# 15:34:50 - LiteLLM:DEBUG: utils.py:6050 - Error getting model info: This model isn't mapped yet. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json
# 15:34:50 - LiteLLM:DEBUG: utils.py:6050 - Error getting model info: This model isn't mapped yet. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json
# DEBUG:LiteLLM:Error getting model info: This model isn't mapped yet. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json
# DEBUG:LiteLLM:Error getting model info: This model isn't mapped yet. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json
# 15:34:50 - LiteLLM:DEBUG: utils.py:2634 - Model not found or error in checking supports_reasoning support. You passed model=my-claude-sonnet-4-5, custom_llm_provider=azure_ai. Error: This model isn't mapped yet. model=my-claude-sonnet-4-5, custom_llm_provider=azure_ai. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json.
# DEBUG:LiteLLM:Model not found or error in checking supports_reasoning support. You passed model=my-claude-sonnet-4-5, custom_llm_provider=azure_ai. Error: This model isn't mapped yet. model=my-claude-sonnet-4-5, custom_llm_provider=azure_ai. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json.
# 15:34:50 - LiteLLM:DEBUG: cost_calculator.py:1730 - litellm.cost_calculator.py::completion_cost() - Error calculating cost for model=azure_ai/my-claude-sonnet-4-5 - This model isn't mapped yet. model=azure_ai/my-claude-sonnet-4-5, custom_llm_provider=azure_ai. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json.
# DEBUG:LiteLLM:litellm.cost_calculator.py::completion_cost() - Error calculating cost for model=azure_ai/my-claude-sonnet-4-5 - This model isn't mapped yet. model=azure_ai/my-claude-sonnet-4-5, custom_llm_provider=azure_ai. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json.
# 15:34:50 - LiteLLM:DEBUG: utils.py:5745 - checking potential_model_names in litellm.model_cost: {'split_model': 'my-claude-sonnet-4-5', 'combined_model_name': 'azure_ai/my-claude-sonnet-4-5', 'stripped_model_name': 'my-claude-sonnet-4-5', 'combined_stripped_model_name': 'azure_ai/my-claude-sonnet-4-5', 'custom_llm_provider': 'azure_ai'}
# DEBUG:LiteLLM:checking potential_model_names in litellm.model_cost: {'split_model': 'my-claude-sonnet-4-5', 'combined_model_name': 'azure_ai/my-claude-sonnet-4-5', 'stripped_model_name': 'my-claude-sonnet-4-5', 'combined_stripped_model_name': 'azure_ai/my-claude-sonnet-4-5', 'custom_llm_provider': 'azure_ai'}
# 15:34:50 - LiteLLM:DEBUG: utils.py:6050 - Error getting model info: This model isn't mapped yet. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json
# DEBUG:LiteLLM:Error getting model info: This model isn't mapped yet. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json
# 15:34:50 - LiteLLM:DEBUG: cost_calculator.py:1730 - litellm.cost_calculator.py::completion_cost() - Error calculating cost for model=my-claude-sonnet-4-5 - This model isn't mapped yet. model=my-claude-sonnet-4-5, custom_llm_provider=azure_ai. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json.
# DEBUG:LiteLLM:litellm.cost_calculator.py::completion_cost() - Error calculating cost for model=my-claude-sonnet-4-5 - This model isn't mapped yet. model=my-claude-sonnet-4-5, custom_llm_provider=azure_ai. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json.
# 15:34:50 - LiteLLM:DEBUG: litellm_logging.py:1583 - response_cost_failure_debug_information: {'error_str': "This model isn't mapped yet. model=azure_ai/my-claude-sonnet-4-5, custom_llm_provider=azure_ai. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json.", 'traceback_str': 'Traceback (most recent call last):\n  File "/usr/local/lib/python3.12/dist-packages/litellm/utils.py", line 5841, in _get_model_info_helper\n    raise ValueError(\nValueError: This model isn\'t mapped yet. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json\n\nDuring handling of the above exception, another exception occurred:\n\nTraceback (most recent call last):\n  File "/usr/local/lib/python3.12/dist-packages/litellm/litellm_core_utils/litellm_logging.py", line 1564, in _response_cost_calculator\n    response_cost = litellm.response_cost_calculator(\n                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "/usr/local/lib/python3.12/dist-packages/litellm/cost_calculator.py", line 1850, in response_cost_calculator\n    raise e\n  File "/usr/local/lib/python3.12/dist-packages/litellm/cost_calculator.py", line 1833, in response_cost_calculator\n    response_cost = completion_cost(\n                    ^^^^^^^^^^^^^^^^\n  File "/usr/local/lib/python3.12/dist-packages/litellm/cost_calculator.py", line 1743, in completion_cost\n    raise e\n  File "/usr/local/lib/python3.12/dist-packages/litellm/cost_calculator.py", line 1736, in completion_cost\n    raise e\n  File "/usr/local/lib/python3.12/dist-packages/litellm/cost_calculator.py", line 1585, in completion_cost\n    ) = cost_per_token(\n        ^^^^^^^^^^^^^^^\n  File "/usr/local/lib/python3.12/dist-packages/litellm/cost_calculator.py", line 614, in cost_per_token\n    return azure_ai_cost_per_token(\n           ^^^^^^^^^^^^^^^^^^^^^^^^\n  File "/usr/local/lib/python3.12/dist-packages/litellm/llms/azure_ai/cost_calculator.py", line 102, in cost_per_token\n    prompt_cost, completion_cost = generic_cost_per_token(\n                                   ^^^^^^^^^^^^^^^^^^^^^^^\n  File "/usr/local/lib/python3.12/dist-packages/litellm/litellm_core_utils/llm_cost_calc/utils.py", line 640, in generic_cost_per_token\n    model_info = get_model_info(model=model, custom_llm_provider=custom_llm_provider)\n                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "/usr/local/lib/python3.12/dist-packages/litellm/utils.py", line 6138, in get_model_info\n    _model_info = _get_model_info_helper(\n                  ^^^^^^^^^^^^^^^^^^^^^^^\n  File "/usr/local/lib/python3.12/dist-packages/litellm/utils.py", line 6051, in _get_model_info_helper\n    raise Exception(\nException: This model isn\'t mapped yet. model=azure_ai/my-claude-sonnet-4-5, custom_llm_provider=azure_ai. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json.\n', 'model': 'azure_ai/my-claude-sonnet-4-5', 'cache_hit': False, 'custom_llm_provider': 'azure_ai', 'base_model': None, 'call_type': 'completion', 'custom_pricing': False}
# DEBUG:LiteLLM:response_cost_failure_debug_information: {'error_str': "This model isn't mapped yet. model=azure_ai/my-claude-sonnet-4-5, custom_llm_provider=azure_ai. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json.", 'traceback_str': 'Traceback (most recent call last):\n  File "/usr/local/lib/python3.12/dist-packages/litellm/utils.py", line 5841, in _get_model_info_helper\n    raise ValueError(\nValueError: This model isn\'t mapped yet. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json\n\nDuring handling of the above exception, another exception occurred:\n\nTraceback (most recent call last):\n  File "/usr/local/lib/python3.12/dist-packages/litellm/litellm_core_utils/litellm_logging.py", line 1564, in _response_cost_calculator\n    response_cost = litellm.response_cost_calculator(\n                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "/usr/local/lib/python3.12/dist-packages/litellm/cost_calculator.py", line 1850, in response_cost_calculator\n    raise e\n  File "/usr/local/lib/python3.12/dist-packages/litellm/cost_calculator.py", line 1833, in response_cost_calculator\n    response_cost = completion_cost(\n                    ^^^^^^^^^^^^^^^^\n  File "/usr/local/lib/python3.12/dist-packages/litellm/cost_calculator.py", line 1743, in completion_cost\n    raise e\n  File "/usr/local/lib/python3.12/dist-packages/litellm/cost_calculator.py", line 1736, in completion_cost\n    raise e\n  File "/usr/local/lib/python3.12/dist-packages/litellm/cost_calculator.py", line 1585, in completion_cost\n    ) = cost_per_token(\n        ^^^^^^^^^^^^^^^\n  File "/usr/local/lib/python3.12/dist-packages/litellm/cost_calculator.py", line 614, in cost_per_token\n    return azure_ai_cost_per_token(\n           ^^^^^^^^^^^^^^^^^^^^^^^^\n  File "/usr/local/lib/python3.12/dist-packages/litellm/llms/azure_ai/cost_calculator.py", line 102, in cost_per_token\n    prompt_cost, completion_cost = generic_cost_per_token(\n                                   ^^^^^^^^^^^^^^^^^^^^^^^\n  File "/usr/local/lib/python3.12/dist-packages/litellm/litellm_core_utils/llm_cost_calc/utils.py", line 640, in generic_cost_per_token\n    model_info = get_model_info(model=model, custom_llm_provider=custom_llm_provider)\n                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "/usr/local/lib/python3.12/dist-packages/litellm/utils.py", line 6138, in get_model_info\n    _model_info = _get_model_info_helper(\n                  ^^^^^^^^^^^^^^^^^^^^^^^\n  File "/usr/local/lib/python3.12/dist-packages/litellm/utils.py", line 6051, in _get_model_info_helper\n    raise Exception(\nException: This model isn\'t mapped yet. model=azure_ai/my-claude-sonnet-4-5, custom_llm_provider=azure_ai. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json.\n', 'model': 'azure_ai/my-claude-sonnet-4-5', 'cache_hit': False, 'custom_llm_provider': 'azure_ai', 'base_model': None, 'call_type': 'completion', 'custom_pricing': False}
# Azure Response
#
# ModelResponse(id='chatcmpl-aafa56c0-3fc1-4c8c-8417-ebb7592a9191', created=1780414489, model='claude-sonnet-4-5-20250929', object='chat.completion', system_fingerprint=None, choices=[Choices(finish_reason='stop', index=0, message=Message(content='Hello! How can I help you today?', role='assistant', tool_calls=None, function_call=None, provider_specific_fields={'citations': None, 'thinking_blocks': None}))], usage=Usage(completion_tokens=12, prompt_tokens=9, total_tokens=21, completion_tokens_details=CompletionTokensDetailsWrapper(accepted_prediction_tokens=None, audio_tokens=None, reasoning_tokens=0, rejected_prediction_tokens=None, text_tokens=12, image_tokens=None, video_tokens=None), prompt_tokens_details=PromptTokensDetailsWrapper(audio_tokens=None, cached_tokens=0, text_tokens=9, image_tokens=None, video_tokens=None, cache_creation_tokens=0, cache_creation_token_details=CacheCreationTokenDetails(ephemeral_5m_input_tokens=0, ephemeral_1h_input_tokens=0)), cache_creation_input_tokens=0, cache_read_input_tokens=0, inference_geo='not_available', speed=None))
# 15:34:50 - LiteLLM:DEBUG: litellm_logging.py:1583 - response_cost_failure_debug_information: {'error_str': "This model isn't mapped yet. model=my-claude-sonnet-4-5, custom_llm_provider=azure_ai. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json.", 'traceback_str': 'Traceback (most recent call last):\n  File "/usr/local/lib/python3.12/dist-packages/litellm/utils.py", line 5841, in _get_model_info_helper\n    raise ValueError(\nValueError: This model isn\'t mapped yet. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json\n\nDuring handling of the above exception, another exception occurred:\n\nTraceback (most recent call last):\n  File "/usr/local/lib/python3.12/dist-packages/litellm/litellm_core_utils/litellm_logging.py", line 1564, in _response_cost_calculator\n    response_cost = litellm.response_cost_calculator(\n                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "/usr/local/lib/python3.12/dist-packages/litellm/cost_calculator.py", line 1850, in response_cost_calculator\n    raise e\n  File "/usr/local/lib/python3.12/dist-packages/litellm/cost_calculator.py", line 1833, in response_cost_calculator\n    response_cost = completion_cost(\n                    ^^^^^^^^^^^^^^^^\n  File "/usr/local/lib/python3.12/dist-packages/litellm/cost_calculator.py", line 1743, in completion_cost\n    raise e\n  File "/usr/local/lib/python3.12/dist-packages/litellm/cost_calculator.py", line 1736, in completion_cost\n    raise e\n  File "/usr/local/lib/python3.12/dist-packages/litellm/cost_calculator.py", line 1585, in completion_cost\n    ) = cost_per_token(\n        ^^^^^^^^^^^^^^^\n  File "/usr/local/lib/python3.12/dist-packages/litellm/cost_calculator.py", line 614, in cost_per_token\n    return azure_ai_cost_per_token(\n           ^^^^^^^^^^^^^^^^^^^^^^^^\n  File "/usr/local/lib/python3.12/dist-packages/litellm/llms/azure_ai/cost_calculator.py", line 102, in cost_per_token\n    prompt_cost, completion_cost = generic_cost_per_token(\n                                   ^^^^^^^^^^^^^^^^^^^^^^^\n  File "/usr/local/lib/python3.12/dist-packages/litellm/litellm_core_utils/llm_cost_calc/utils.py", line 640, in generic_cost_per_token\n    model_info = get_model_info(model=model, custom_llm_provider=custom_llm_provider)\n                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "/usr/local/lib/python3.12/dist-packages/litellm/utils.py", line 6138, in get_model_info\n    _model_info = _get_model_info_helper(\n                  ^^^^^^^^^^^^^^^^^^^^^^^\n  File "/usr/local/lib/python3.12/dist-packages/litellm/utils.py", line 6051, in _get_model_info_helper\n    raise Exception(\nException: This model isn\'t mapped yet. model=my-claude-sonnet-4-5, custom_llm_provider=azure_ai. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json.\n', 'model': 'my-claude-sonnet-4-5', 'cache_hit': None, 'custom_llm_provider': 'azure_ai', 'base_model': None, 'call_type': 'completion', 'custom_pricing': False}
# DEBUG:LiteLLM:response_cost_failure_debug_information: {'error_str': "This model isn't mapped yet. model=my-claude-sonnet-4-5, custom_llm_provider=azure_ai. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json.", 'traceback_str': 'Traceback (most recent call last):\n  File "/usr/local/lib/python3.12/dist-packages/litellm/utils.py", line 5841, in _get_model_info_helper\n    raise ValueError(\nValueError: This model isn\'t mapped yet. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json\n\nDuring handling of the above exception, another exception occurred:\n\nTraceback (most recent call last):\n  File "/usr/local/lib/python3.12/dist-packages/litellm/litellm_core_utils/litellm_logging.py", line 1564, in _response_cost_calculator\n    response_cost = litellm.response_cost_calculator(\n                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "/usr/local/lib/python3.12/dist-packages/litellm/cost_calculator.py", line 1850, in response_cost_calculator\n    raise e\n  File "/usr/local/lib/python3.12/dist-packages/litellm/cost_calculator.py", line 1833, in response_cost_calculator\n    response_cost = completion_cost(\n                    ^^^^^^^^^^^^^^^^\n  File "/usr/local/lib/python3.12/dist-packages/litellm/cost_calculator.py", line 1743, in completion_cost\n    raise e\n  File "/usr/local/lib/python3.12/dist-packages/litellm/cost_calculator.py", line 1736, in completion_cost\n    raise e\n  File "/usr/local/lib/python3.12/dist-packages/litellm/cost_calculator.py", line 1585, in completion_cost\n    ) = cost_per_token(\n        ^^^^^^^^^^^^^^^\n  File "/usr/local/lib/python3.12/dist-packages/litellm/cost_calculator.py", line 614, in cost_per_token\n    return azure_ai_cost_per_token(\n           ^^^^^^^^^^^^^^^^^^^^^^^^\n  File "/usr/local/lib/python3.12/dist-packages/litellm/llms/azure_ai/cost_calculator.py", line 102, in cost_per_token\n    prompt_cost, completion_cost = generic_cost_per_token(\n                                   ^^^^^^^^^^^^^^^^^^^^^^^\n  File "/usr/local/lib/python3.12/dist-packages/litellm/litellm_core_utils/llm_cost_calc/utils.py", line 640, in generic_cost_per_token\n    model_info = get_model_info(model=model, custom_llm_provider=custom_llm_provider)\n                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "/usr/local/lib/python3.12/dist-packages/litellm/utils.py", line 6138, in get_model_info\n    _model_info = _get_model_info_helper(\n                  ^^^^^^^^^^^^^^^^^^^^^^^\n  File "/usr/local/lib/python3.12/dist-packages/litellm/utils.py", line 6051, in _get_model_info_helper\n    raise Exception(\nException: This model isn\'t mapped yet. model=my-claude-sonnet-4-5, custom_llm_provider=azure_ai. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json.\n', 'model': 'my-claude-sonnet-4-5', 'cache_hit': None, 'custom_llm_provider': 'azure_ai', 'base_model': None, 'call_type': 'completion', 'custom_pricing': False}
# 15:34:50 - LiteLLM:DEBUG: utils.py:5745 - checking potential_model_names in litellm.model_cost: {'split_model': 'claude-sonnet-4-5-20250929', 'combined_model_name': 'azure_ai/claude-sonnet-4-5-20250929', 'stripped_model_name': 'claude-sonnet-4-5-20250929', 'combined_stripped_model_name': 'azure_ai/claude-sonnet-4-5-20250929', 'custom_llm_provider': 'azure_ai'}

# %% [markdown]
# ### *Foundry Anthropic (anthropic)*

# %%
from litellm import completion
from google.colab import userdata
import os

response = completion(
    model = "anthropic/my-claude-sonnet-4-5",
    api_base="https://hb-1959-resource.services.ai.azure.com/anthropic",
    api_key=userdata.get('AZURE_ANTHROPIC_API_KEY'),
    messages = [{"role": "user", "content": "Hello!"}]
)
print("Azure Response\n")
print(response)
# Out:
# 15:40:45 - LiteLLM:DEBUG: utils.py:485 -
#
# DEBUG:LiteLLM:
#
# 15:40:45 - LiteLLM:DEBUG: utils.py:485 - Request to litellm:
# DEBUG:LiteLLM:Request to litellm:
# 15:40:45 - LiteLLM:DEBUG: utils.py:485 - litellm.completion(model='anthropic/my-claude-sonnet-4-5', api_base='https://hb-1959-resource.services.ai.azure.com/anthropic', REDACTED', messages=[{'role': 'user', 'content': 'Hello!'}])
# DEBUG:LiteLLM:litellm.completion(model='anthropic/my-claude-sonnet-4-5', api_base='https://hb-1959-resource.services.ai.azure.com/anthropic', REDACTED', messages=[{'role': 'user', 'content': 'Hello!'}])
# 15:40:45 - LiteLLM:DEBUG: utils.py:485 -
#
# DEBUG:LiteLLM:
#
# 15:40:45 - LiteLLM:DEBUG: utils.py:1011 - Removing thought signatures from tool call IDs for non-Gemini model
# DEBUG:LiteLLM:Removing thought signatures from tool call IDs for non-Gemini model
# 15:40:45 - LiteLLM:DEBUG: litellm_logging.py:563 - self.optional_params: {}
# DEBUG:LiteLLM:self.optional_params: {}
# 15:40:45 - LiteLLM:DEBUG: utils.py:485 - SYNC kwargs[caching]: False; litellm.cache: None; kwargs.get('cache')['no-cache']: False
# DEBUG:LiteLLM:SYNC kwargs[caching]: False; litellm.cache: None; kwargs.get('cache')['no-cache']: False
# 15:40:45 - LiteLLM:DEBUG: utils.py:5745 - checking potential_model_names in litellm.model_cost: {'split_model': 'my-claude-sonnet-4-5', 'combined_model_name': 'anthropic/my-claude-sonnet-4-5', 'stripped_model_name': 'my-claude-sonnet-4-5', 'combined_stripped_model_name': 'anthropic/my-claude-sonnet-4-5', 'custom_llm_provider': 'anthropic'}
# DEBUG:LiteLLM:checking potential_model_names in litellm.model_cost: {'split_model': 'my-claude-sonnet-4-5', 'combined_model_name': 'anthropic/my-claude-sonnet-4-5', 'stripped_model_name': 'my-claude-sonnet-4-5', 'combined_stripped_model_name': 'anthropic/my-claude-sonnet-4-5', 'custom_llm_provider': 'anthropic'}
# 15:40:45 - LiteLLM:DEBUG: utils.py:6050 - Error getting model info: This model isn't mapped yet. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json
# DEBUG:LiteLLM:Error getting model info: This model isn't mapped yet. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json
# 15:40:45 - LiteLLM:DEBUG: main.py:985 - Error getting model info: This model isn't mapped yet. model=my-claude-sonnet-4-5, custom_llm_provider=anthropic. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json.
# DEBUG:LiteLLM:Error getting model info: This model isn't mapped yet. model=my-claude-sonnet-4-5, custom_llm_provider=anthropic. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json.
# 15:40:45 - LiteLLM:DEBUG: utils.py:5745 - checking potential_model_names in litellm.model_cost: {'split_model': 'my-claude-sonnet-4-5', 'combined_model_name': 'anthropic/my-claude-sonnet-4-5', 'stripped_model_name': 'my-claude-sonnet-4-5', 'combined_stripped_model_name': 'anthropic/my-claude-sonnet-4-5', 'custom_llm_provider': 'anthropic'}
# DEBUG:LiteLLM:checking potential_model_names in litellm.model_cost: {'split_model': 'my-claude-sonnet-4-5', 'combined_model_name': 'anthropic/my-claude-sonnet-4-5', 'stripped_model_name': 'my-claude-sonnet-4-5', 'combined_stripped_model_name': 'anthropic/my-claude-sonnet-4-5', 'custom_llm_provider': 'anthropic'}
# 15:40:45 - LiteLLM:DEBUG: utils.py:6050 - Error getting model info: This model isn't mapped yet. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json
# DEBUG:LiteLLM:Error getting model info: This model isn't mapped yet. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json
# 15:40:45 - LiteLLM:DEBUG: utils.py:2634 - Model not found or error in checking supports_reasoning support. You passed model=my-claude-sonnet-4-5, custom_llm_provider=anthropic. Error: This model isn't mapped yet. model=my-claude-sonnet-4-5, custom_llm_provider=anthropic. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json.
# DEBUG:LiteLLM:Model not found or error in checking supports_reasoning support. You passed model=my-claude-sonnet-4-5, custom_llm_provider=anthropic. Error: This model isn't mapped yet. model=my-claude-sonnet-4-5, custom_llm_provider=anthropic. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json.
# 15:40:45 - LiteLLM:INFO: utils.py:4083 -
# LiteLLM completion() model= my-claude-sonnet-4-5; provider = anthropic
# INFO:LiteLLM:
# LiteLLM completion() model= my-claude-sonnet-4-5; provider = anthropic
# 15:40:45 - LiteLLM:DEBUG: utils.py:4086 -
# LiteLLM: Params passed to completion() {'model': 'my-claude-sonnet-4-5', 'functions': None, 'function_call': None, 'temperature': None, 'top_p': None, 'n': None, 'stream': None, 'stream_options': None, 'stop': None, 'max_tokens': None, 'max_completion_tokens': None, 'modalities': None, 'prediction': None, 'audio': None, 'presence_penalty': None, 'frequency_penalty': None, 'logit_bias': None, 'user': None, 'custom_llm_provider': 'anthropic', 'response_format': None, 'seed': None, 'tools': None, 'tool_choice': None, 'max_retries': None, 'logprobs': None, 'top_logprobs': None, 'extra_headers': None, 'api_version': None, 'parallel_tool_calls': None, 'drop_params': None, 'allowed_openai_params': None, 'reasoning_effort': None, 'verbosity': None, 'additional_drop_params': None, 'messages': [{'role': 'user', 'content': 'Hello!'}], 'thinking': None, 'web_search_options': None, 'safety_identifier': None, 'service_tier': None}
# DEBUG:LiteLLM:
# LiteLLM: Params passed to completion() {'model': 'my-claude-sonnet-4-5', 'functions': None, 'function_call': None, 'temperature': None, 'top_p': None, 'n': None, 'stream': None, 'stream_options': None, 'stop': None, 'max_tokens': None, 'max_completion_tokens': None, 'modalities': None, 'prediction': None, 'audio': None, 'presence_penalty': None, 'frequency_penalty': None, 'logit_bias': None, 'user': None, 'custom_llm_provider': 'anthropic', 'response_format': None, 'seed': None, 'tools': None, 'tool_choice': None, 'max_retries': None, 'logprobs': None, 'top_logprobs': None, 'extra_headers': None, 'api_version': None, 'parallel_tool_calls': None, 'drop_params': None, 'allowed_openai_params': None, 'reasoning_effort': None, 'verbosity': None, 'additional_drop_params': None, 'messages': [{'role': 'user', 'content': 'Hello!'}], 'thinking': None, 'web_search_options': None, 'safety_identifier': None, 'service_tier': None}
# 15:40:45 - LiteLLM:DEBUG: utils.py:4089 -
# LiteLLM: Non-Default params passed to completion() {}
# DEBUG:LiteLLM:
# LiteLLM: Non-Default params passed to completion() {}
# 15:40:45 - LiteLLM:DEBUG: utils.py:485 - Final returned optional params: {}
# DEBUG:LiteLLM:Final returned optional params: {}
# 15:40:45 - LiteLLM:DEBUG: litellm_logging.py:563 - self.optional_params: {}
# DEBUG:LiteLLM:self.optional_params: {}
# 15:40:45 - LiteLLM:DEBUG: utils.py:5745 - checking potential_model_names in litellm.model_cost: {'split_model': 'my-claude-sonnet-4-5', 'combined_model_name': 'anthropic/my-claude-sonnet-4-5', 'stripped_model_name': 'my-claude-sonnet-4-5', 'combined_stripped_model_name': 'anthropic/my-claude-sonnet-4-5', 'custom_llm_provider': 'anthropic'}
# DEBUG:LiteLLM:checking potential_model_names in litellm.model_cost: {'split_model': 'my-claude-sonnet-4-5', 'combined_model_name': 'anthropic/my-claude-sonnet-4-5', 'stripped_model_name': 'my-claude-sonnet-4-5', 'combined_stripped_model_name': 'anthropic/my-claude-sonnet-4-5', 'custom_llm_provider': 'anthropic'}
# 15:40:45 - LiteLLM:DEBUG: utils.py:6050 - Error getting model info: This model isn't mapped yet. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json
# DEBUG:LiteLLM:Error getting model info: This model isn't mapped yet. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json
# 15:40:45 - LiteLLM:DEBUG: main.py:985 - Error getting model info: This model isn't mapped yet. model=my-claude-sonnet-4-5, custom_llm_provider=anthropic. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json.
# DEBUG:LiteLLM:Error getting model info: This model isn't mapped yet. model=my-claude-sonnet-4-5, custom_llm_provider=anthropic. Add it here - https://github.com/BerriAI/litellm/blob/main/model_prices_and_context_window.json.
# 15:40:45 - LiteLLM:DEBUG: utils.py:2634 - Model not found or error in checking supports_adaptive_thinking support. You passed model=my-claude-sonnet-4-5, custom_llm_provider=None. Error: litellm.BadRequestError: LLM Provider NOT provided. Pass in the LLM provider you are trying to call. You passed model=my-claude-sonnet-4-5
#  Pass model as E.g. For 'Huggingface' inference endpoints pass in `completion(model='huggingface/starcoder',..)` Learn more: https://docs.litellm.ai/docs/providers
# DEBUG:LiteLLM:Model not found or error in checking supports_adaptive_thinking support. You passed model=my-claude-sonnet-4-5, custom_llm_provider=None. Error: litellm.BadRequestError: LLM Provider NOT provided. Pass in the LLM provider you are trying to call. You passed model=my-claude-sonnet-4-5
#  Pass model as E.g. For 'Huggingface' inference endpoints pass in `completion(model='huggingface/starcoder',..)` Learn more: https://docs.litellm.ai/docs/providers
# 15:40:45 - LiteLLM:DEBUG: litellm_logging.py:1170 -
#
# POST Request Sent from LiteLLM:
# curl -X POST \
# https://hb-1959-resource.services.ai.azure.com/anthropic/v1/messages \
# -H 'anthropic-version: 2023-06-01' -H 'accept: application/json' -H 'content-type: application/json' -H 'REDACTED' \
# -d '{'model': 'my-claude-sonnet-4-5', 'messages': [{'role': 'user', 'content': [{'type': 'text', 'text': 'Hello!'}]}], 'max_tokens': 4096}'
#
#
# DEBUG:LiteLLM:
#
# POST Request Sent from LiteLLM:
# curl -X POST \
# https://hb-1959-resource.services.ai.azure.com/anthropic/v1/messages \
# -H 'anthropic-version: 2023-06-01' -H 'accept: application/json' -H 'content-type: application/json' -H 'REDACTED' \
# -d '{'model': 'my-claude-sonnet-4-5', 'messages': [{'role': 'user', 'content': [{'type': 'text', 'text': 'Hello!'}]}], 'max_tokens': 4096}'
#
#
# 15:40:45 - LiteLLM:DEBUG: main.py:7434 - _is_function_call: False
# DEBUG:LiteLLM:_is_function_call: False
# Provider List: https://docs.litellm.ai/docs/providers
#
#
# Provider List: https://docs.litellm.ai/docs/providers
# 15:40:47 - LiteLLM:DEBUG: litellm_logging.py:1243 - RAW RESPONSE:
# {"model":"claude-sonnet-4-5-20250929","id":"msg_0117qEici529hJMxfhm7iV5x","type":"message","role":"assistant","content":[{"type":"text","text":"Hello! How can I help you today?"}],"stop_reason":"end_turn","stop_sequence":null,"stop_details":null,"usage":{"input_tokens":9,"cache_creation_input_tokens":0,"cache_read_input_tokens":0,"cache_creation":{"ephemeral_5m_input_tokens":0,"ephemeral_1h_input_tokens":0},"output_tokens":12,"service_tier":"standard","inference_geo":"not_available"}}
#
#
# DEBUG:LiteLLM:RAW RESPONSE:
# {"model":"claude-sonnet-4-5-20250929","id":"msg_0117qEici529hJMxfhm7iV5x","type":"message","role":"assistant","content":[{"type":"text","text":"Hello! How can I help you today?"}],"stop_reason":"end_turn","stop_sequence":null,"stop_details":null,"usage":{"input_tokens":9,"cache_creation_input_tokens":0,"cache_read_input_tokens":0,"cache_creation":{"ephemeral_5m_input_tokens":0,"ephemeral_1h_input_tokens":0},"output_tokens":12,"service_tier":"standard","inference_geo":"not_available"}}
#
#
# 15:40:47 - LiteLLM:INFO: utils.py:1656 - Wrapper: Completed Call, calling success_handler
# INFO:LiteLLM:Wrapper: Completed Call, calling success_handler
# 15:40:47 - LiteLLM:DEBUG: cost_calculator.py:1212 - selected model name for cost calculation: anthropic/claude-sonnet-4-5-20250929
# DEBUG:LiteLLM:selected model name for cost calculation: anthropic/claude-sonnet-4-5-20250929
# 15:40:47 - LiteLLM:DEBUG: litellm_logging.py:2017 - Logging Details LiteLLM-Success Call: Cache_hit=None
# DEBUG:LiteLLM:Logging Details LiteLLM-Success Call: Cache_hit=None
# 15:40:47 - LiteLLM:DEBUG: litellm_logging.py:1568 - response_cost: 0.00020700000000000002
# DEBUG:LiteLLM:response_cost: 0.00020700000000000002
# 15:40:47 - LiteLLM:DEBUG: cost_calculator.py:1212 - selected model name for cost calculation: anthropic/claude-sonnet-4-5-20250929
# Azure Response
#
# ModelResponse(id='chatcmpl-e01bc40d-f52e-4716-9c9c-098819fe9caa', created=1780414847, model='claude-sonnet-4-5-20250929', object='chat.completion', system_fingerprint=None, choices=[Choices(finish_reason='stop', index=0, message=Message(content='Hello! How can I help you today?', role='assistant', tool_calls=None, function_call=None, provider_specific_fields={'citations': None, 'thinking_blocks': None}))], usage=Usage(completion_tokens=12, prompt_tokens=9, total_tokens=21, completion_tokens_details=CompletionTokensDetailsWrapper(accepted_prediction_tokens=None, audio_tokens=None, reasoning_tokens=0, rejected_prediction_tokens=None, text_tokens=12, image_tokens=None, video_tokens=None), prompt_tokens_details=PromptTokensDetailsWrapper(audio_tokens=None, cached_tokens=0, text_tokens=9, image_tokens=None, video_tokens=None, cache_creation_tokens=0, cache_creation_token_details=CacheCreationTokenDetails(ephemeral_5m_input_tokens=0, ephemeral_1h_input_tokens=0)), cache_creation_input_tokens=0, cache_read_input_tokens=0, inference_geo='not_available', speed=None))
# DEBUG:LiteLLM:selected model name for cost calculation: anthropic/claude-sonnet-4-5-20250929
# 15:40:47 - LiteLLM:DEBUG: litellm_logging.py:1568 - response_cost: 0.00020700000000000002
# DEBUG:LiteLLM:response_cost: 0.00020700000000000002
# 15:40:47 - LiteLLM:DEBUG: utils.py:5745 - checking potential_model_names in litellm.model_cost: {'split_model': 'claude-sonnet-4-5-20250929', 'combined_model_name': 'anthropic/claude-sonnet-4-5-20250929', 'stripped_model_name': 'claude-sonnet-4-5-20250929', 'combined_stripped_model_name': 'anthropic/claude-sonnet-4-5-20250929', 'custom_llm_provider': 'anthropic'}
# DEBUG:LiteLLM:checking potential_model_names in litellm.model_cost: {'split_model': 'claude-sonnet-4-5-20250929', 'combined_model_name': 'anthropic/claude-sonnet-4-5-20250929', 'stripped_model_name': 'claude-sonnet-4-5-20250929', 'combined_stripped_model_name': 'anthropic/claude-sonnet-4-5-20250929', 'custom_llm_provider': 'anthropic'}
